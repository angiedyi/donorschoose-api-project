# %%
import csv
import os
import requests as req
import json
from collections import Counter

# %%
#Donorschoose.org API
api_key = "DONORSCHOOSE"
url = "https://api.donorschoose.org/common/json_feed.html?max=100"

# %%
#Open a CSV for a list of Bay Area cities
with open("bayarea_cities.csv") as cities:
    cities_reader = csv.reader(cities)
    
    cities = [city[0] for city in cities_reader]
    
    print(len(cities))

cities = cities[39:57]
print(cities)
# Out:
# 102
# ['Lafayette', 'Larkspur', 'Livermore', 'Los Altos', 'Los Altos Hills', 'Los Gatos', 'Martinez', 'Menlo Park', 'Mill Valley', 'Millbrae', 'Milpitas', 'Monte Sereno', 'Moraga', 'Morgan Hill', 'Mountain View', 'Napa', 'Newark', 'Novato']

# %%
# Build partial query URL
query_url = url + "&APIkey=" + api_key + "&state=CA" + "&cityName="
#location_data = [req.get(query_url + city).json() for city in cities]

all_data = {}

for city in cities:
    
    results = req.get(query_url + city).json()
    all_data[city] = results   

print(json.dumps(all_data, indent=2))
# Out:
# {
#   "Lafayette": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=Lafayette&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "0",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": []
#   },
#   "Larkspur": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=Larkspur&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "0",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": []
#   },
#   "Livermore": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=Livermore&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "60",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": [
#       {
#         "id": "2717040",
#         "hashCode": "-1678370116",
#         "proposalURL": "https://www.donorschoose.org/project/current-technology-for-current-events/2717040/?verify=-1678370116&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2717040&donationAmount=45&verify=-1678370116&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4458307_sm.jpg?timestamp=1494632680457",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4458307_retina.jpg?timestamp=1494632680457",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4458307_thmb.jpg?timestamp=1494632680457",
#         "title": "Current Technology for Current Events",
#         "shortDescription": "We are the staff of our school's student newspaper, El Vaquerito. We're learning the basics of news writing, journalism, digital media and web design and using our direct hands-on experience...",
#         "fulfillmentTrailer": "My students need a set of laptop computers so they can produce our school news website and design our physical newspaper. Help us obtain and learn to use the latest technology!",
#         "snippets": [],
#         "percentFunded": "44",
#         "numDonors": "17",
#         "costToComplete": "1256.24",
#         "studentLed": false,
#         "numStudents": "16",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "2253.88",
#         "freeShipping": "true",
#         "teacherId": "4458307",
#         "teacherName": "Ms. Sarraille",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Livermore High School",
#         "schoolUrl": "https://www.donorschoose.org/school/livermore-high-school/3857/",
#         "city": "Livermore",
#         "zip": "94550-3298",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.680489000000000",
#         "longitude": "-121.761525000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "3",
#           "name": "Literature &amp; Writing",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "16",
#             "name": "College &amp; Career Prep",
#             "groupId": "5"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2017-12-18",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2939554",
#         "hashCode": "-1857517768",
#         "proposalURL": "https://www.donorschoose.org/project/inclusive-communication-and-learning-cen/2939554/?verify=-1857517768&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2939554&donationAmount=45&verify=-1857517768&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3089573_sm.jpg?timestamp=1511912305017",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3089573_retina.jpg?timestamp=1511912305017",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3089573_thmb.jpg?timestamp=1511912305017",
#         "title": "Inclusive Communication and Learning Center",
#         "shortDescription": "Our Inclusive Communication and Learning Center (iCal Center) is designed to support all special education students across our district. <br /><br />Communication is a basic human right, yet my students all...",
#         "fulfillmentTrailer": "My students need access to a color printer and toners so that adapted materials can be created to help support their communication and learning throughout their day.",
#         "snippets": [],
#         "percentFunded": "58",
#         "numDonors": "7",
#         "costToComplete": "329.46",
#         "studentLed": false,
#         "numStudents": "60",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "789.46",
#         "freeShipping": "true",
#         "teacherId": "3089573",
#         "teacherName": "Mrs. Garcia-Chavez",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Leo Croce Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/leo-croce-elementary-school/3870/",
#         "city": "Livermore",
#         "zip": "94551-1224",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.717167000000000",
#         "longitude": "-121.728651000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "23",
#           "name": "Special Needs",
#           "groupId": "7"
#         },
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-03-21",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2933506",
#         "hashCode": "1335724952",
#         "proposalURL": "https://www.donorschoose.org/project/talk-to-the-hand/2933506/?verify=1335724952&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2933506&donationAmount=45&verify=1335724952&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u12713_sm.jpg?timestamp=1413855801929",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u12713_retina.jpg?timestamp=1413855801929",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u12713_thmb.jpg?timestamp=1413855801929",
#         "title": "Talk to the Hand",
#         "shortDescription": "Hello, Hola, xin cho, Hall, , Kamusta, Ol, , and welcome to this Born This Way Foundation inspired project to encourage mental and emotional well-being in a class of energetic and enthusiastic...",
#         "fulfillmentTrailer": "My students need hand and finger puppets, a book, boxes of staples, and domino trays.",
#         "snippets": [],
#         "percentFunded": "46",
#         "numDonors": "3",
#         "costToComplete": "264.81",
#         "studentLed": false,
#         "numStudents": "26",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "BTW_18",
#           "ownerRegion": "",
#           "name": "Born This Way Foundation",
#           "donorSalutation": "Born This Way Foundation",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/bornthisway_250.png",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=BTW_18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/bornthisway_250.png\"></p>\r\n<p>Donations to this project are now being matched, thanks to support from Born This Way Foundation.</p>\r\n<p> Co-founded by Lady Gaga and her mother, Cynthia Germanotta, the foundation supports the wellness of young people and empowers them to create a kinder, braver world by fostering kinder communities, improved mental health resources, and more positive environments \u2014online and offline.</p>\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1319\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "491.16",
#         "freeShipping": "true",
#         "teacherId": "12713",
#         "teacherName": "Ms. Y.",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 7,
#             "name": "U.S. Cellular Teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Jackson Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jackson-avenue-elementary-school/3861/",
#         "city": "Livermore",
#         "zip": "94550-3400",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684967000000000",
#         "longitude": "-121.742363000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "26",
#           "name": "Character Education",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "12",
#             "name": "Music",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "15",
#           "name": "Educational Kits &amp; Games"
#         },
#         "expirationDate": "2018-04-06",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "1420296",
#         "hashCode": "-791702032",
#         "proposalURL": "https://www.donorschoose.org/project/its-hip-to-be-square/1420296/?verify=-791702032&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=1420296&donationAmount=45&verify=-791702032&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u12713_sm.jpg?timestamp=1413855801929",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u12713_retina.jpg?timestamp=1413855801929",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u12713_thmb.jpg?timestamp=1413855801929",
#         "title": "It&#039;s Hip to Be Square",
#         "shortDescription": "When budget cuts eliminated the elementary music program, teachers and parents stepped up to voluntarily provide music education to our deserving students. With your help, they can be heard. Hola,...",
#         "fulfillmentTrailer": "My students need a wireless head mic, song and movement books, props, cds, shakers, brayers, and a hot pot.",
#         "snippets": [],
#         "percentFunded": "61",
#         "numDonors": "4",
#         "costToComplete": "445.36",
#         "studentLed": false,
#         "numStudents": "40",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "CARNEGIE18",
#           "ownerRegion": "",
#           "name": "Carnegie Corporation",
#           "donorSalutation": "Carnegie Corporation",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/carnegie_250.png",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=CARNEGIE18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/carnegie_250.png\"></p>\r\n<p>Donations to this project are now being matched, thanks to support from Carnegie Corporation. </p>\r\n<p>Carnegie Corporation was established to promote the advancement and diffusion of knowledge and understanding. In keeping with this mandate, the Corporation\u2019s work focuses on the issues of international peace, the advancement of education and knowledge, and the strength of our democracy.</p>\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1312\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "1152.25",
#         "freeShipping": "false",
#         "teacherId": "12713",
#         "teacherName": "Ms. Y.",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 7,
#             "name": "U.S. Cellular Teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Jackson Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jackson-avenue-elementary-school/3861/",
#         "city": "Livermore",
#         "zip": "94550-3400",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684967000000000",
#         "longitude": "-121.742363000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "20",
#           "name": "Parent Involvement",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "12",
#             "name": "Music",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "17",
#           "name": "Musical Instruments"
#         },
#         "expirationDate": "2018-03-30",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2761732",
#         "hashCode": "-1431892299",
#         "proposalURL": "https://www.donorschoose.org/project/21-century-classroom/2761732/?verify=-1431892299&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2761732&donationAmount=45&verify=-1431892299&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3834128_sm.jpg?timestamp=1473385159044",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3834128_retina.jpg?timestamp=1473385159044",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3834128_thmb.jpg?timestamp=1473385159044",
#         "title": "21 Century Classroom",
#         "shortDescription": "My students come from a lower socio-economic area of our city. A large percentage of my students are on the free and/or reduced lunch and breakfast program. We do not have the same items in our...",
#         "fulfillmentTrailer": "My students need access to technology so they have a better chance of succeeding in the 21st century!",
#         "snippets": [],
#         "percentFunded": "3",
#         "numDonors": "1",
#         "costToComplete": "946.53",
#         "studentLed": false,
#         "numStudents": "21",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "971.53",
#         "freeShipping": "true",
#         "teacherId": "3834128",
#         "teacherName": "Mrs. Robinson",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than three\u2011quarters of students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGH",
#           "name": "More than three\u2011quarters of students from low\u2011income households",
#           "range": "76-89%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 21,
#             "name": "Head Start"
#           }
#         ],
#         "schoolName": "Marylin Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/marylin-avenue-elementary-school/3864/",
#         "city": "Livermore",
#         "zip": "94551-6500",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684795000000000",
#         "longitude": "-121.785995000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "22",
#           "name": "Foreign Languages",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "25",
#             "name": "ESL",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-11",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2961940",
#         "hashCode": "-1611062257",
#         "proposalURL": "https://www.donorschoose.org/project/pollination-models-science-engineering/2961940/?verify=-1611062257&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2961940&donationAmount=45&verify=-1611062257&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4455512_sm.jpg?timestamp=1494480505989",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4455512_retina.jpg?timestamp=1494480505989",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4455512_thmb.jpg?timestamp=1494480505989",
#         "title": "Pollination Models: Science, Engineering, &amp; Art, Oh My!",
#         "shortDescription": "My students come from very diverse backgrounds with varying degrees of world experience. They speak different languages, share unique cultures, and many of them are socioeconomically challenged....",
#         "fulfillmentTrailer": "My students need some air-dry modeling clay, glitter glue, and supplemental supplies for making 3-D flower models to simulate the environmentally important process of pollination.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "187.82",
#         "studentLed": false,
#         "numStudents": "80",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "187.82",
#         "freeShipping": "true",
#         "teacherId": "4455512",
#         "teacherName": "Mrs. Weetman",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Jackson Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jackson-avenue-elementary-school/3861/",
#         "city": "Livermore",
#         "zip": "94550-3400",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684967000000000",
#         "longitude": "-121.742363000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "7",
#           "name": "Environmental Science",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "11",
#             "name": "Visual Arts",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "16",
#           "name": "Art Supplies"
#         },
#         "expirationDate": "2018-04-07",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2919088",
#         "hashCode": "196689734",
#         "proposalURL": "https://www.donorschoose.org/project/personalized-learning-in-kindergarten/2919088/?verify=196689734&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2919088&donationAmount=45&verify=196689734&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u107144_sm.jpg?timestamp=1208458209000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u107144_retina.jpg?timestamp=1208458209000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u107144_thmb.jpg?timestamp=1208458209000",
#         "title": "Personalized Learning in Kindergarten!",
#         "shortDescription": "I teach Kindergarten in a Title I northern California elementary school. I have several second language learners, two identified special needs children, some students who have gone to TK or...",
#         "fulfillmentTrailer": "My students need three Acer Chromebooks for personalized learning time in Math, Reading and even Science.",
#         "snippets": [],
#         "percentFunded": "17",
#         "numDonors": "5",
#         "costToComplete": "811.72",
#         "studentLed": false,
#         "numStudents": "27",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "980.14",
#         "freeShipping": "true",
#         "teacherId": "107144",
#         "teacherName": "Mrs. Voegele",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 7,
#             "name": "U.S. Cellular Teacher"
#           },
#           {
#             "id": 9,
#             "name": "NEA member"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Jackson Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jackson-avenue-elementary-school/3861/",
#         "city": "Livermore",
#         "zip": "94550-3400",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684967000000000",
#         "longitude": "-121.742363000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "8",
#             "name": "Mathematics",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-03-21",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2704269",
#         "hashCode": "-1715685159",
#         "proposalURL": "https://www.donorschoose.org/project/kmotion-stools-help-us-learn/2704269/?verify=-1715685159&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2704269&donationAmount=45&verify=-1715685159&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u44179_sm.jpg?timestamp=1472526120633",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u44179_retina.jpg?timestamp=1472526120633",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u44179_thmb.jpg?timestamp=1472526120633",
#         "title": "K&#039;Motion Stools Help Us Learn",
#         "shortDescription": "I teach 26 eager Kindergarten students who come to school everyday with great big smiles on their faces! They are excited to learn, play and be with their friends. They come from a wide variety of...",
#         "fulfillmentTrailer": "My students need kids sized K'Motion Stools to help get the wiggles out and assist in their learning.",
#         "snippets": [],
#         "percentFunded": "26",
#         "numDonors": "5",
#         "costToComplete": "542.86",
#         "studentLed": false,
#         "numStudents": "26",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "737.86",
#         "freeShipping": "true",
#         "teacherId": "44179",
#         "teacherName": "Mrs. Helms",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Leo Croce Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/leo-croce-elementary-school/3870/",
#         "city": "Livermore",
#         "zip": "94551-1224",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.717167000000000",
#         "longitude": "-121.728651000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "23",
#           "name": "Special Needs",
#           "groupId": "7"
#         },
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-11",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2968768",
#         "hashCode": "555079355",
#         "proposalURL": "https://www.donorschoose.org/project/growing-minds-bodies-need-ergonomics/2968768/?verify=555079355&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2968768&donationAmount=45&verify=555079355&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1894489_sm.jpg?timestamp=1461878365140",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1894489_retina.jpg?timestamp=1461878365140",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1894489_thmb.jpg?timestamp=1461878365140",
#         "title": "Growing Minds &amp; Bodies Need Ergonomics!",
#         "shortDescription": "My students would greatly benefit from having access to an engaging activity to allow them to have another avenue to think critically and work as a collaborative team. This is a unique learning...",
#         "fulfillmentTrailer": "My students need seating options in our classroom. By adding two standing desks and two ergonomic kneeling chairs my students will have the flexibility of movement.",
#         "snippets": [],
#         "percentFunded": "24",
#         "numDonors": "4",
#         "costToComplete": "281.07",
#         "studentLed": false,
#         "numStudents": "90",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "371.07",
#         "freeShipping": "true",
#         "teacherId": "1894489",
#         "teacherName": "Mrs. Elliott",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "William Mendenhall Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/william-mendenhall-middle-school/3865/",
#         "city": "Livermore",
#         "zip": "94550-6215",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.662709000000000",
#         "longitude": "-121.792366000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "15",
#           "name": "Social Sciences",
#           "groupId": "3"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "12",
#           "name": "Flexible Seating"
#         },
#         "expirationDate": "2018-04-07",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2761477",
#         "hashCode": "-1431892554",
#         "proposalURL": "https://www.donorschoose.org/project/custom-work-shirt-creations/2761477/?verify=-1431892554&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2761477&donationAmount=45&verify=-1431892554&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1347387_sm.jpg?timestamp=1473213317099",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1347387_retina.jpg?timestamp=1473213317099",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1347387_thmb.jpg?timestamp=1473213317099",
#         "title": "Custom Work Shirt Creations",
#         "shortDescription": "My students are some of the coolest students on the block. The amount of growth that takes place in my classroom daily is immeasurable. Every one of my students are dealt a different hand in life....",
#         "fulfillmentTrailer": "My students need to create a job work shirt when they go out to their job sites. Thanks to our wonderful community, our students work 4 days a week (2 hours) at 10 different job sites.  We need Circuit.",
#         "snippets": [],
#         "percentFunded": "41",
#         "numDonors": "3",
#         "costToComplete": "568.11",
#         "studentLed": false,
#         "numStudents": "28",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "960.75",
#         "freeShipping": "true",
#         "teacherId": "1347387",
#         "teacherName": "Mrs. Booe",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Granada High School",
#         "schoolUrl": "https://www.donorschoose.org/school/granada-high-school/3856/",
#         "city": "Livermore",
#         "zip": "94550-4099",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.675373000000000",
#         "longitude": "-121.789636000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "23",
#           "name": "Special Needs",
#           "groupId": "7"
#         },
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-01",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2918117",
#         "hashCode": "1261105019",
#         "proposalURL": "https://www.donorschoose.org/project/work-in-peace/2918117/?verify=1261105019&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2918117&donationAmount=45&verify=1261105019&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3802077_sm.jpg?timestamp=1472687786086",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3802077_retina.jpg?timestamp=1472687786086",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3802077_thmb.jpg?timestamp=1472687786086",
#         "title": "Work in Peace",
#         "shortDescription": "Low income, English Language Learners are some of the best students I could ask for. Most of my students are eager and ready to learn. Some are being raised in single parent homes, receiving a...",
#         "fulfillmentTrailer": "My students need headphones and mice for their in class computers to make it easier to hear them to work without distractions.",
#         "snippets": [],
#         "percentFunded": "1",
#         "numDonors": "1",
#         "costToComplete": "680.86",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "teacherFFPromoCodeFund": {
#           "eligible": "true",
#           "deadline": "December 11",
#           "code": "LIFTOFF",
#           "matchingKey": "teachProm8P",
#           "ownerRegion": "National",
#           "name": "Matching Donor",
#           "donorSalutation": "The DonorsChoose.org Community",
#           "type": "PROMO",
#           "logoURL": "liftoff.gif",
#           "description": ""
#         },
#         "totalPrice": "690.86",
#         "freeShipping": "true",
#         "teacherId": "3802077",
#         "teacherName": "Mrs. Martinez",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than three\u2011quarters of students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGH",
#           "name": "More than three\u2011quarters of students from low\u2011income households",
#           "range": "76-89%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 21,
#             "name": "Head Start"
#           }
#         ],
#         "schoolName": "Marylin Avenue Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/marylin-avenue-elementary-school/3864/",
#         "city": "Livermore",
#         "zip": "94551-6500",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684795000000000",
#         "longitude": "-121.785995000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "25",
#           "name": "ESL",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "8",
#             "name": "Mathematics",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-04-03",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2755257",
#         "hashCode": "-367482518",
#         "proposalURL": "https://www.donorschoose.org/project/quality-baseball/2755257/?verify=-367482518&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2755257&donationAmount=45&verify=-367482518&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4744334_sm.jpg?timestamp=1504215921228",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4744334_retina.jpg?timestamp=1504215921228",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4744334_thmb.jpg?timestamp=1504215921228",
#         "title": "Quality Baseball",
#         "shortDescription": "My school offers a comprehensive Physical Education program. We offer programs varying from yoga to weight lifting to baseball to swimming to line and swing dancing and many more. We strive to...",
#         "fulfillmentTrailer": "My students need good practice baseballs for our baseball class. The Wilson A1030 baseball has proven to perform well and last long under the daily wear and tear of baseball class practice.",
#         "snippets": [],
#         "percentFunded": "10",
#         "numDonors": "1",
#         "costToComplete": "475.65",
#         "studentLed": false,
#         "numStudents": "95",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "530.65",
#         "freeShipping": "true",
#         "teacherId": "4744334",
#         "teacherName": "Mr. Willis",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Granada High School",
#         "schoolUrl": "https://www.donorschoose.org/school/granada-high-school/3856/",
#         "city": "Livermore",
#         "zip": "94550-4099",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.675373000000000",
#         "longitude": "-121.789636000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "2",
#           "name": "Team Sports",
#           "groupId": "2"
#         },
#         "additionalSubjects": [
#           {
#             "id": "27",
#             "name": "Health &amp; Wellness",
#             "groupId": "2"
#           }
#         ],
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-01",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2806399",
#         "hashCode": "-180920016",
#         "proposalURL": "https://www.donorschoose.org/project/for-the-love-of-osmos/2806399/?verify=-180920016&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2806399&donationAmount=45&verify=-180920016&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u309412_sm.jpg?timestamp=1313268683000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u309412_retina.jpg?timestamp=1313268683000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u309412_thmb.jpg?timestamp=1313268683000",
#         "title": "For The Love Of Osmos",
#         "shortDescription": "As a teacher in a lower-income school, my students are faced with several challenges both in and out of the classroom. With so many challenges, it is important to keep our learning environment...",
#         "fulfillmentTrailer": "My students need technology that will inspire their love of learning!",
#         "snippets": [],
#         "percentFunded": "32",
#         "numDonors": "3",
#         "costToComplete": "243.68",
#         "studentLed": false,
#         "numStudents": "26",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "360.68",
#         "freeShipping": "true",
#         "teacherId": "309412",
#         "teacherName": "Mrs. Morris",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Arroyo Seco Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/arroyo-seco-elementary-school/3866/",
#         "city": "Livermore",
#         "zip": "94550-3508",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.684582000000000",
#         "longitude": "-121.728172000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "8",
#           "name": "Mathematics",
#           "groupId": "4"
#         },
# ...
#         "gradeLevel": {
#           "id": "2",
#           "name": "Grades 3-5"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           }
#         ],
#         "schoolName": "Hamilton Meadow Park Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/hamilton-meadow-park-elementary-school/4302/",
#         "city": "Novato",
#         "zip": "94949-6423",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.054413050413132",
#         "longitude": "-122.530284225940700",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "8",
#           "name": "Mathematics",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "4",
#           "name": "Trips"
#         },
#         "expirationDate": "2017-12-16",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2782771",
#         "hashCode": "808868068",
#         "proposalURL": "https://www.donorschoose.org/project/ipads-help-first-graders-learn-and-colla/2782771/?verify=808868068&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2782771&donationAmount=45&verify=808868068&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4641283_sm.jpg?timestamp=1505699932272",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4641283_retina.jpg?timestamp=1505699932272",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4641283_thmb.jpg?timestamp=1505699932272",
#         "title": "iPads Help First Graders Learn and Collaborate",
#         "shortDescription": "I have 22 excited and eager learners who come from varying socio-economic and cultural backgrounds. They all have a great desire to learn and \"grow their brain\" but often get frustrated when their...",
#         "fulfillmentTrailer": "My students need four updated iPads that are compatible with software programs offered at our school.",
#         "snippets": [],
#         "percentFunded": "31",
#         "numDonors": "9",
#         "costToComplete": "1207.11",
#         "studentLed": false,
#         "numStudents": "22",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1753.58",
#         "freeShipping": "true",
#         "teacherId": "4641283",
#         "teacherName": "Mrs. Prince",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Rancho Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/rancho-elementary-school/4308/",
#         "city": "Novato",
#         "zip": "94947-4497",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.095047000000000",
#         "longitude": "-122.571152000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "8",
#           "name": "Mathematics",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "10",
#             "name": "Literacy",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-17",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2949153",
#         "hashCode": "1544871452",
#         "proposalURL": "https://www.donorschoose.org/project/supplies-for-success/2949153/?verify=1544871452&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2949153&donationAmount=45&verify=1544871452&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3703980_sm.jpg?timestamp=1472050245071",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3703980_retina.jpg?timestamp=1472050245071",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3703980_thmb.jpg?timestamp=1472050245071",
#         "title": "Supplies for Success",
#         "shortDescription": "Our students vary in socioeconomic status, with over half being on the free lunch program. We are a combined 6th, 7th and 8th grade classroom with students that have educational difficulties (such...",
#         "fulfillmentTrailer": "My students need school supplies like pencils, erasers, backpacks, etc., for success! Mistakes are learning tools.",
#         "snippets": [],
#         "percentFunded": "23",
#         "numDonors": "1",
#         "costToComplete": "324.11",
#         "studentLed": false,
#         "numStudents": "13",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "423.11",
#         "freeShipping": "true",
#         "teacherId": "3703980",
#         "teacherName": "Mrs. M.",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 6,
#             "name": "Vocational Education"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "San Jose Intermediate School",
#         "schoolUrl": "https://www.donorschoose.org/school/san-jose-middle-school/4311/",
#         "city": "Novato",
#         "zip": "94949-4952",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.075571000000000",
#         "longitude": "-122.568385000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "31",
#           "name": "Warmth, Care &amp; Hunger",
#           "groupId": "8"
#         },
#         "resource": {
#           "id": "10",
#           "name": "Classroom Basics"
#         },
#         "expirationDate": "2018-03-28",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2943313",
#         "hashCode": "-755795481",
#         "proposalURL": "https://www.donorschoose.org/project/biotechnology-for-my-biology-classroom/2943313/?verify=-755795481&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2943313&donationAmount=45&verify=-755795481&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4997262_sm.jpg?timestamp=1511587606408",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4997262_retina.jpg?timestamp=1511587606408",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4997262_thmb.jpg?timestamp=1511587606408",
#         "title": "Biotechnology for my Biology Classroom",
#         "shortDescription": "The students at my school come from a diverse population within our bay area community. Our school is home to an award winning arts school within a school. We also have a strong ELD program...",
#         "fulfillmentTrailer": "My students need supportive technology to increase their learning interest and potential.",
#         "snippets": [],
#         "percentFunded": "9",
#         "numDonors": "2",
#         "costToComplete": "716.94",
#         "studentLed": false,
#         "numStudents": "147",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "791.94",
#         "freeShipping": "true",
#         "teacherId": "4997262",
#         "teacherName": "Ms. Nicklasson",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 4,
#             "name": "Magnet"
#           },
#           {
#             "id": 6,
#             "name": "Vocational Education"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Novato High School",
#         "schoolUrl": "https://www.donorschoose.org/school/novato-high-school/4300/",
#         "city": "Novato",
#         "zip": "94947-4499",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.089111000000000",
#         "longitude": "-122.573044000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "4",
#           "name": "Health &amp; Life Science",
#           "groupId": "4"
#         },
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-03-25",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2961747",
#         "hashCode": "-546646194",
#         "proposalURL": "https://www.donorschoose.org/project/creating-a-strong-21st-century-classroom/2961747/?verify=-546646194&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2961747&donationAmount=45&verify=-546646194&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3114746_sm.jpg?timestamp=1478640093829",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3114746_retina.jpg?timestamp=1478640093829",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3114746_thmb.jpg?timestamp=1478640093829",
#         "title": "Creating a Strong 21st Century Classroom With Technology for All",
#         "shortDescription": "My students are 21 aspiring students, coming from a variety of different backgrounds. Living in a small town, north of San Francisco, our school serves a population of about 400 students. About...",
#         "fulfillmentTrailer": "My students need 11 Chromebooks and power strips to allow us to continue to utilize the unlimited 21st century opportunities that Google apps offer for students.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "2352.28",
#         "studentLed": false,
#         "numStudents": "21",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "2352.28",
#         "freeShipping": "true",
#         "teacherId": "3114746",
#         "teacherName": "Ms. Cruz",
#         "gradeLevel": {
#           "id": "2",
#           "name": "Grades 3-5"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 12,
#             "name": "Horace Mann (partner)"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Loma Verde Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/loma-verde-elementary-school/4303/",
#         "city": "Novato",
#         "zip": "94949-5998",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.064568000000000",
#         "longitude": "-122.547272000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "7",
#             "name": "Environmental Science",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-04-06",
#         "fundingStatus": "needs funding"
#       }
#     ]
#   }
# }

# %%
city_data = {}

for cityname, data in all_data.items():
        
    #step 1: get cost to complete
    #step 2: get povertyType label
    #step 3: add this to the output vairable
    
    costcomplete = []
    povertytype = []
    
    data["proposals"]
    
    for x in data["proposals"]:
        
        costcomplete.append(float(x["costToComplete"]))
        povertytype.append(x["povertyType"]["label"])
    
    city_data[cityname] = {
        
        "costToComplete": sum(costcomplete),
        "povertyType": Counter(povertytype)
    }

city_data
# Out:
# {'Lafayette': {'costToComplete': 0, 'povertyType': Counter()},
#  'Larkspur': {'costToComplete': 0, 'povertyType': Counter()},
#  'Livermore': {'costToComplete': 38009.59999999999,
#   'povertyType': Counter({'HIGH': 2,
#            'LOW': 26,
#            'MODERATE': 11,
#            'MODERATELOW': 11})},
#  'Los Altos': {'costToComplete': 233.25, 'povertyType': Counter({'LOW': 1})},
#  'Los Altos Hills': {'costToComplete': 0, 'povertyType': Counter()},
#  'Los Gatos': {'costToComplete': 0, 'povertyType': Counter()},
#  'Martinez': {'costToComplete': 21526.749999999996,
#   'povertyType': Counter({'LOW': 7, 'MODERATE': 5, 'MODERATELOW': 9})},
#  'Menlo Park': {'costToComplete': 31500.0,
#   'povertyType': Counter({'HIGHEST': 29})},
#  'Mill Valley': {'costToComplete': 0, 'povertyType': Counter()},
#  'Millbrae': {'costToComplete': 0, 'povertyType': Counter()},
#  'Milpitas': {'costToComplete': 4966.76,
#   'povertyType': Counter({'LOW': 1, 'MODERATELOW': 5})},
#  'Monte Sereno': {'costToComplete': 0, 'povertyType': Counter()},
#  'Moraga': {'costToComplete': 0, 'povertyType': Counter()},
#  'Morgan Hill': {'costToComplete': 2069.59,
#   'povertyType': Counter({'HIGH': 3, 'MODERATELOW': 1})},
#  'Mountain View': {'costToComplete': 3488.46,
#   'povertyType': Counter({'HIGHEST': 2,
#            'MODERATE': 1,
#            'MODERATEHIGH': 1,
#            'MODERATELOW': 1})},
#  'Napa': {'costToComplete': 10790.23,
#   'povertyType': Counter({'HIGH': 1, 'LOW': 5, 'MODERATE': 3})},
#  'Newark': {'costToComplete': 7330.279999999999,
#   'povertyType': Counter({'LOW': 1, 'MODERATEHIGH': 8})},
#  'Novato': {'costToComplete': 5267.120000000001,
#   'povertyType': Counter({'LOW': 1,
#            'MODERATE': 1,
#            'MODERATEHIGH': 2,
#            'MODERATELOW': 2})}}

# %%
#list of cityname, costtocomplete, number of low, number of modeatelow, etc.

csv_data = []

citynames = sorted(city_data.keys())

for cityname in citynames: 
    
    data = city_data[cityname]
    
    one_row = []
    
    one_row.append(cityname)
    one_row.append(data['costToComplete'])  
    
    labeltype = ["LOW", "MODERATELOW", "MODERATE", "MODERATEHIGH", "HIGH", "HIGHEST", "UNKNOWN"]
    
    for x in labeltype:
        
        one_row.append(data['povertyType'].get(x, 0))
    
    csv_data.append(one_row)

csv_data
# Out:
# [['Lafayette', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Larkspur', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Livermore', 38009.59999999999, 26, 11, 11, 0, 2, 0, 0],
#  ['Los Altos', 233.25, 1, 0, 0, 0, 0, 0, 0],
#  ['Los Altos Hills', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Los Gatos', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Martinez', 21526.749999999996, 7, 9, 5, 0, 0, 0, 0],
#  ['Menlo Park', 31500.0, 0, 0, 0, 0, 0, 29, 0],
#  ['Mill Valley', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Millbrae', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Milpitas', 4966.76, 1, 5, 0, 0, 0, 0, 0],
#  ['Monte Sereno', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Moraga', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Morgan Hill', 2069.59, 0, 1, 0, 0, 3, 0, 0],
#  ['Mountain View', 3488.46, 0, 1, 1, 1, 0, 2, 0],
#  ['Napa', 10790.23, 5, 0, 3, 0, 1, 0, 0],
#  ['Newark', 7330.279999999999, 1, 0, 0, 8, 0, 0, 0],
#  ['Novato', 5267.120000000001, 1, 2, 1, 2, 0, 0, 0]]

# %%
root_path = os.path.join(os.getcwd())
data_path = os.path.join(root_path)
csvpath = os.path.join(root_path, "donorschoose_api.csv")
with open(csvpath, "a", newline="") as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=",")
    csvwriter.writerows(csv_data)
