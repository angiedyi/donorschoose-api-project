# %%
import csv
import os
import requests as req
import json
from collections import Counter

# %%
#Donorschoose.org API
api_key = "DONORSCHOOSE"
url = "https://api.donorschoose.org/common/json_feed.html?max=100"

# %%
#Open a CSV for a list of Bay Area cities
with open("bayarea_cities.csv") as cities:
    cities_reader = csv.reader(cities)
    
    cities = [city[0] for city in cities_reader]
    
    print(len(cities))

cities = cities[74:94]
print(cities)
# Out:
# 102
# ['St. Helena', 'San Anselmo', 'San Bruno', 'San Carlos', 'San Francisco', 'San Jose', 'San Leandro', 'San Mateo', 'San Pablo', 'San Rafael', 'San Ramon', 'Santa Clara', 'Santa Rosa', 'Saratoga', 'Sausalito', 'Sebastopol', 'Sonoma', 'South San Francisco', 'Suisun City', 'Sunnyvale']

# %%
# Build partial query URL
query_url = url + "&APIkey=" + api_key + "&state=CA" + "&cityName="
#location_data = [req.get(query_url + city).json() for city in cities]

all_data = {}

for city in cities:
    
    results = req.get(query_url + city).json()
    all_data[city] = results   

print(json.dumps(all_data, indent=2))
# Out:
# {
#   "St. Helena": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=St.+Helena&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "0",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": []
#   },
#   "San Anselmo": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=San+Anselmo&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "0",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": []
#   },
#   "San Bruno": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=San+Bruno&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "3",
#     "index": "0",
#     "max": "3",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": [
#       {
#         "id": "2765380",
#         "hashCode": "1798662389",
#         "proposalURL": "https://www.donorschoose.org/project/chart-stand-to-bring-learning-to-life/2765380/?verify=1798662389&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2765380&donationAmount=45&verify=1798662389&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4532568_sm.jpg?timestamp=1503789719108",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4532568_retina.jpg?timestamp=1503789719108",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4532568_thmb.jpg?timestamp=1503789719108",
#         "title": "Chart Stand To Bring Learning To Life",
#         "shortDescription": "I teach in a school that is designated Title I, meaning many students come from socioeconomically disadvantaged homes and receive free and reduced-price lunch. About half of my class are English...",
#         "fulfillmentTrailer": "My students need a chart stand to be able to see and help comprehend the complicated curriculum they learn each and every day.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "323.28",
#         "studentLed": false,
#         "numStudents": "26",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "323.28",
#         "freeShipping": "true",
#         "teacherId": "4532568",
#         "teacherName": "Mrs. Medrano",
#         "gradeLevel": {
#           "id": "2",
#           "name": "Grades 3-5"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Lomita Park Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/lomita-park-elementary-school/4561/",
#         "city": "San Bruno",
#         "zip": "94066-5331",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.612139000000000",
#         "longitude": "-122.400809000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "3",
#           "name": "Literature &amp; Writing",
#           "groupId": "6"
#         },
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-16",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2892842",
#         "hashCode": "-1839419328",
#         "proposalURL": "https://www.donorschoose.org/project/steam-combinging-science-technology-en/2892842/?verify=-1839419328&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2892842&donationAmount=45&verify=-1839419328&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u210849_sm.jpg?timestamp=1374437494131",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u210849_retina.jpg?timestamp=1374437494131",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u210849_thmb.jpg?timestamp=1374437494131",
#         "title": "STEAM Combinging Science, Technology, Engineering, Art, and Math",
#         "shortDescription": "I teach math and science core, incorporating hands-on, project-based learning in my classroom. I also teach a speech and technology elective, helping students develop 21st-century presentation...",
#         "fulfillmentTrailer": "My students need STEAM supplies to incorporate art into their STEM projects: a 3D printer and filament, card stock, iPad, and more.",
#         "snippets": [],
#         "percentFunded": "13",
#         "numDonors": "3",
#         "costToComplete": "871.15",
#         "studentLed": false,
#         "numStudents": "120",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "998.15",
#         "freeShipping": "true",
#         "teacherId": "210849",
#         "teacherName": "Mrs. Taylor-Salvador",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 9,
#             "name": "NEA member"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           },
#           {
#             "id": 1,
#             "name": "Teach For America"
#           }
#         ],
#         "schoolTypes": [],
#         "schoolName": "Parkside Intermediate School",
#         "schoolUrl": "https://www.donorschoose.org/school/parkside-intermediate-school/4600/",
#         "city": "San Bruno",
#         "zip": "94066-4197",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.615761000000000",
#         "longitude": "-122.418610000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "6",
#           "name": "Applied Sciences",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "11",
#             "name": "Visual Arts",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-02-28",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2893152",
#         "hashCode": "-1839419018",
#         "proposalURL": "https://www.donorschoose.org/project/steam-science-art-and-innovation/2893152/?verify=-1839419018&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2893152&donationAmount=45&verify=-1839419018&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u210849_sm.jpg?timestamp=1374437494131",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u210849_retina.jpg?timestamp=1374437494131",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u210849_thmb.jpg?timestamp=1374437494131",
#         "title": "STEAM Science, Art, and Innovation",
#         "shortDescription": "I teach math and science core, incorporating hands-on, project-based learning in my classroom. I also teach a speech and technology elective, helping students develop 21st-century presentation...",
#         "fulfillmentTrailer": "My students need a Surface Pro and iPads for our STEAM classroom. We need innovation to create, design, and promote 21st century skills.",
#         "snippets": [],
#         "percentFunded": "1",
#         "numDonors": "2",
#         "costToComplete": "5555.62",
#         "studentLed": false,
#         "numStudents": "90",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "5630.62",
#         "freeShipping": "true",
#         "teacherId": "210849",
#         "teacherName": "Mrs. Taylor-Salvador",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 9,
#             "name": "NEA member"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           },
#           {
#             "id": 1,
#             "name": "Teach For America"
#           }
#         ],
#         "schoolTypes": [],
#         "schoolName": "Parkside Intermediate School",
#         "schoolUrl": "https://www.donorschoose.org/school/parkside-intermediate-school/4600/",
#         "city": "San Bruno",
#         "zip": "94066-4197",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.615761000000000",
#         "longitude": "-122.418610000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "6",
#           "name": "Applied Sciences",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "8",
#             "name": "Mathematics",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-03-22",
#         "fundingStatus": "needs funding"
#       }
#     ]
#   },
#   "San Carlos": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=San+Carlos&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "1",
#     "index": "0",
#     "max": "1",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": [
#       {
#         "id": "2819614",
#         "hashCode": "2022530255",
#         "proposalURL": "https://www.donorschoose.org/project/stand-up-desks-active-learning-for-enga/2819614/?verify=2022530255&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2819614&donationAmount=45&verify=2022530255&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3917932_sm.jpg?timestamp=1478033075362",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3917932_retina.jpg?timestamp=1478033075362",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3917932_thmb.jpg?timestamp=1478033075362",
#         "title": "Stand Up Desks: Active Learning for Engaged Students",
#         "shortDescription": "SCCLC s a community of children, parents, and educators who value social emotional growth, problem solving, and service learning. My learners are accepting of others and celebrate each other's...",
#         "fulfillmentTrailer": "My students need flexible work spaces to support children's various learning styles and needs.",
#         "snippets": [],
#         "percentFunded": "8",
#         "numDonors": "5",
#         "costToComplete": "2020.91",
#         "studentLed": false,
#         "numStudents": "44",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "2205.91",
#         "freeShipping": "true",
#         "teacherId": "3917932",
#         "teacherName": "Ms. C.",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 1,
#             "name": "Charter"
#           },
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "San Carlos Charter Learning Center",
#         "schoolUrl": "https://www.donorschoose.org/school/san-carlos-charter-learning-ctr/4608/",
#         "city": "San Carlos",
#         "zip": "94070-1769",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.507942000000000",
#         "longitude": "-122.285151000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "23",
#           "name": "Special Needs",
#           "groupId": "7"
#         },
#         "additionalSubjects": [
#           {
#             "id": "27",
#             "name": "Health &amp; Wellness",
#             "groupId": "2"
#           }
#         ],
#         "resource": {
#           "id": "13",
#           "name": "Reading Nooks, Desks &amp; Storage"
#         },
#         "expirationDate": "2018-02-11",
#         "fundingStatus": "needs funding"
#       }
#     ]
#   },
#   "San Francisco": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=San+Francisco&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "187",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": [
#       {
#         "id": "2790422",
#         "hashCode": "-1319956793",
#         "proposalURL": "https://www.donorschoose.org/project/getting-tech-savy-with-tablets/2790422/?verify=-1319956793&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2790422&donationAmount=45&verify=-1319956793&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3712280_sm.jpg?timestamp=1470029755875",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3712280_retina.jpg?timestamp=1470029755875",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3712280_thmb.jpg?timestamp=1470029755875",
#         "title": "Getting Tech Savy With Tablets",
#         "shortDescription": "In our room, we work hard to be better than we were yesterday. Our classroom facilitates independence and agency by having differentiated work to promote the most growth. We foster a sense of...",
#         "fulfillmentTrailer": "My students need a class set of tablets for phonic apps, math games, and video access.",
#         "snippets": [],
#         "percentFunded": "77",
#         "numDonors": "11",
#         "costToComplete": "147.49",
#         "studentLed": false,
#         "numStudents": "20",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "639.14",
#         "freeShipping": "true",
#         "teacherId": "3712280",
#         "teacherName": "Ms. Yang",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Nearly all students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGHEST",
#           "name": "Nearly all students from low\u2011income households",
#           "range": "90%+",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Hillcrest Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/hillcrest-elementary-school/4433/",
#         "city": "San Francisco",
#         "zip": "94134-1098",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.728943000000000",
#         "longitude": "-122.419158000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-02-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2929808",
#         "hashCode": "-830413530",
#         "proposalURL": "https://www.donorschoose.org/project/lifelong-literacy-learners/2929808/?verify=-830413530&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2929808&donationAmount=45&verify=-830413530&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3646215_sm.jpg?timestamp=1466810352122",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3646215_retina.jpg?timestamp=1466810352122",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3646215_thmb.jpg?timestamp=1466810352122",
#         "title": "Lifelong Literacy Learners",
#         "shortDescription": "It is such a joy to teach in a classroom with great ethnic and socio-economic diversity. Students in my classroom come from various neighborhoods in San Francisco eager for the hands-on,...",
#         "fulfillmentTrailer": "I need funding to attend a 3 day Phonics Institute hosted by Teachers College Reading and Writing Project in New York, New York to develop my",
#         "snippets": [],
#         "percentFunded": "76",
#         "numDonors": "6",
#         "costToComplete": "238.82",
#         "studentLed": false,
#         "numStudents": "16",
#         "professionalDevelopment": true,
#         "matchingFund": {
#           "matchingKey": "GATESPD18",
#           "ownerRegion": "",
#           "name": "The Bill &amp; Melinda Gates Foundation",
#           "donorSalutation": "The Bill &amp; Melinda Gates Foundation",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/gates_large.gif",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=GATESPD18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/gates_large.gif\"></p>\r\n\r\n<p>Donations to this project are now being matched, thanks to support from The Bill & Melinda Gates Foundation. Teachers are learners, too! The Gates Foundation is thrilled to support professional development opportunities and looks forward to hearing about teachers\u2019 experiences. When teachers invest in their development, they help to create student-ready schools.</p>\r\n\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1297\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "990.59",
#         "freeShipping": "true",
#         "teacherId": "3646215",
#         "teacherName": "Ms. Mullarkey",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "San Francisco Community Alternative School",
#         "schoolUrl": "https://www.donorschoose.org/school/san-francisco-community-alternative-school/4485/",
#         "city": "San Francisco",
#         "zip": "94112-2041",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.725848000000000",
#         "longitude": "-122.432466000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "4",
#           "name": "Trips"
#         },
#         "expirationDate": "2017-12-18",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2807367",
#         "hashCode": "-1245335304",
#         "proposalURL": "https://www.donorschoose.org/project/guided-reading-books/2807367/?verify=-1245335304&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2807367&donationAmount=45&verify=-1245335304&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u721469_sm.jpg?timestamp=1409110894347",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u721469_retina.jpg?timestamp=1409110894347",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u721469_thmb.jpg?timestamp=1409110894347",
#         "title": "Guided Reading Books!",
#         "shortDescription": "My students come from different socioeconomic backgrounds. Some might have more, and some might have less. However, this does not change their love for learning. They are all eager to learn....",
#         "fulfillmentTrailer": "My students need a variety selections of guided reading books to accelerate their reading.",
#         "snippets": [],
#         "percentFunded": "96",
#         "numDonors": "25",
#         "costToComplete": "107.82",
#         "studentLed": false,
#         "numStudents": "22",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "2792.15",
#         "freeShipping": "false",
#         "teacherId": "721469",
#         "teacherName": "Ms. Li",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Jose Ortega Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jose-ortega-elementary-school/4438/",
#         "city": "San Francisco",
#         "zip": "94132-3193",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.716236000000000",
#         "longitude": "-122.466397000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "resource": {
#           "id": "1",
#           "name": "Books"
#         },
#         "expirationDate": "2018-01-21",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2717134",
#         "hashCode": "-1678370022",
#         "proposalURL": "https://www.donorschoose.org/project/hooray-for-chromebooks/2717134/?verify=-1678370022&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2717134&donationAmount=45&verify=-1678370022&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u137156_sm.jpg?timestamp=1379544494708",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u137156_retina.jpg?timestamp=1379544494708",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u137156_thmb.jpg?timestamp=1379544494708",
#         "title": "Hooray for Chromebooks!",
#         "shortDescription": "My students are bright and are eager to develop their technology skills. I would love for my students to become proficient at typing, researching, and ultimately be prepared for the future. My...",
#         "fulfillmentTrailer": "My students need Chromebooks, headphones, and a Tech Tub so they can have access to typing, researching, and reading programs.",
#         "snippets": [],
#         "percentFunded": "64",
#         "numDonors": "13",
#         "costToComplete": "717.42",
#         "studentLed": false,
#         "numStudents": "20",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "2012.42",
#         "freeShipping": "false",
#         "teacherId": "137156",
#         "teacherName": "Ms. Hunt",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than three\u2011quarters of students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGH",
#           "name": "More than three\u2011quarters of students from low\u2011income households",
#           "range": "76-89%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 9,
#             "name": "NEA member"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Visitacion Valley Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/visitacion-valley-elementary-school/4463/",
#         "city": "San Francisco",
#         "zip": "94134-2798",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.712670000000000",
#         "longitude": "-122.410242000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2017-12-18",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2944449",
#         "hashCode": "1410340439",
#         "proposalURL": "https://www.donorschoose.org/project/second-life-increasing-storage-capacity/2944449/?verify=1410340439&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2944449&donationAmount=45&verify=1410340439&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u2212771_sm.jpg?timestamp=1502916205260",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u2212771_retina.jpg?timestamp=1502916205260",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u2212771_thmb.jpg?timestamp=1502916205260",
#         "title": "Second Life: Increasing Storage Capacity",
#         "shortDescription": "Our HH students live in San Francisco. They come from a variety of neighborhood districts from the Mission District, Excelsior District, Sunset District, and Bayview District. HH Middle School as...",
#         "fulfillmentTrailer": "My students need twelve 320 GB hard drives so they can store and continue producing high quality work on their computers.",
#         "snippets": [],
#         "percentFunded": "29",
#         "numDonors": "2",
#         "costToComplete": "247.56",
#         "studentLed": false,
#         "numStudents": "32",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "ANONARTS_18",
#           "ownerRegion": "",
#           "name": "An Anonymous Donor",
#           "donorSalutation": "An Anonymous Donor",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/anonymous_large.gif",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=ANONARTS_18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/anonymous_large.gif\"></p>\r\n<p>Donations to this project are now being matched, thanks to support from an anonymous donor. The arts are an essential part of every child's education. An education in the arts makes children well-rounded, engaged, and active citizens of the world. This project has been supported in an effort to ensure that all students gain from the many benefits that arts education provides.</p>\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1267\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "347.56",
#         "freeShipping": "true",
#         "teacherId": "2212771",
#         "teacherName": "Mr. Aringo",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Herbert Hoover Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/herbert-hoover-middle-school/4468/",
#         "city": "San Francisco",
#         "zip": "94116-1841",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.745462000000000",
#         "longitude": "-122.470210000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "6",
#           "name": "Applied Sciences",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "11",
#             "name": "Visual Arts",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-04-04",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2548564",
#         "hashCode": "-788617770",
#         "proposalURL": "https://www.donorschoose.org/project/plan-build-construct-learn/2548564/?verify=-788617770&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2548564&donationAmount=45&verify=-788617770&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u23648_sm.jpg?timestamp=1494600134362",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u23648_retina.jpg?timestamp=1494600134362",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u23648_thmb.jpg?timestamp=1494600134362",
#         "title": "Plan, Build, Construct, Learn",
#         "shortDescription": "My students love to learn. Their loving families send them to school every day ready to collaborate, make mistakes, have fun, and work hard. Most of the students at our school qualify for the free...",
#         "fulfillmentTrailer": "My students need additional Magna-tiles and cars for more open-ended engineering.",
#         "snippets": [],
#         "percentFunded": "44",
#         "numDonors": "2",
#         "costToComplete": "137.38",
#         "studentLed": false,
#         "numStudents": "22",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "247.38",
#         "freeShipping": "true",
#         "teacherId": "23648",
#         "teacherName": "Ms. Moless",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Nearly all students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGHEST",
#           "name": "Nearly all students from low\u2011income households",
#           "range": "90%+",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 1,
#             "name": "Teach For America"
#           },
#           {
#             "id": 9,
#             "name": "NEA member"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Junipero Serra Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/junipero-serra-elementary-school/4439/",
#         "city": "San Francisco",
#         "zip": "94110-5815",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.736582000000000",
#         "longitude": "-122.421195000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "8",
#           "name": "Mathematics",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "6",
#             "name": "Applied Sciences",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "15",
#           "name": "Educational Kits &amp; Games"
#         },
#         "expirationDate": "2018-02-11",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2947899",
#         "hashCode": "345927633",
#         "proposalURL": "https://www.donorschoose.org/project/all-that-glitters-and-sparkles/2947899/?verify=345927633&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2947899&donationAmount=45&verify=345927633&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1037865_sm.jpg?timestamp=1475732349586",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1037865_retina.jpg?timestamp=1475732349586",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1037865_thmb.jpg?timestamp=1475732349586",
#         "title": "All that Glitters and Sparkles!",
#         "shortDescription": "The majority of my students come from low socioeconomic backgrounds and 85% qualify for free/reduced-price school lunch. My diverse Kindergartners represent a plethora of cultures and linguistic...",
#         "fulfillmentTrailer": "My students need air dry clay, paint, buttons, sequins, pipe cleaners, glitter glue, large craft sticks, beads, pom poms, magnets, and other art embellishments.",
#         "snippets": [],
#         "percentFunded": "51",
#         "numDonors": "3",
#         "costToComplete": "137.41",
#         "studentLed": false,
#         "numStudents": "22",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "283.29",
#         "freeShipping": "false",
#         "teacherId": "1037865",
#         "teacherName": "Ms. Quan",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than three\u2011quarters of students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGH",
#           "name": "More than three\u2011quarters of students from low\u2011income households",
#           "range": "76-89%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Redding Elementary School @ Sarah B Cooper School",
#         "schoolUrl": "https://www.donorschoose.org/school/redding-elementary-school/4451/",
#         "city": "San Francisco",
#         "zip": "94133",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.800678961995900",
#         "longitude": "-122.414953819984000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "18",
#           "name": "Early Development",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "11",
#             "name": "Visual Arts",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "16",
#           "name": "Art Supplies"
#         },
#         "expirationDate": "2018-03-27",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2679156",
#         "hashCode": "338517696",
#         "proposalURL": "https://www.donorschoose.org/project/a-special-reading-station/2679156/?verify=338517696&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2679156&donationAmount=45&verify=338517696&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1006423_sm.jpg?timestamp=1468005779416",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1006423_retina.jpg?timestamp=1468005779416",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1006423_thmb.jpg?timestamp=1468005779416",
#         "title": "A Special Reading Station!",
#         "shortDescription": "The scholars in my classroom are a lively bunch of joyful learners! We recognize that each student has a unique story and special interests that they bring into class. Our classroom systems are...",
#         "fulfillmentTrailer": "My students need a reading couch, pouf seats, and floor cushions.",
#         "snippets": [],
#         "percentFunded": "67",
#         "numDonors": "14",
#         "costToComplete": "326.55",
#         "studentLed": false,
#         "numStudents": "22",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "999.87",
#         "freeShipping": "true",
#         "teacherId": "1006423",
#         "teacherName": "Ms. Serra",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Jose Ortega Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/jose-ortega-elementary-school/4438/",
#         "city": "San Francisco",
#         "zip": "94132-3193",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.716236000000000",
#         "longitude": "-122.466397000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "27",
#             "name": "Health &amp; Wellness",
#             "groupId": "2"
#           }
#         ],
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2017-12-17",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2779913",
#         "hashCode": "-1357269574",
#         "proposalURL": "https://www.donorschoose.org/project/guided-readers-for-young-learners/2779913/?verify=-1357269574&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2779913&donationAmount=45&verify=-1357269574&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u109300_sm.jpg?timestamp=1283491223000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u109300_retina.jpg?timestamp=1283491223000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u109300_thmb.jpg?timestamp=1283491223000",
#         "title": "Guided Readers for Young Learners",
#         "shortDescription": "These students attend a public school in San Francisco, where the diversity is immense in all aspects. Students come to our school with varying socioeconomic backgrounds, differing English...",
#         "fulfillmentTrailer": "My students need sets of guided reading books at their instructional level.",
#         "snippets": [],
#         "percentFunded": "88",
#         "numDonors": "6",
#         "costToComplete": "436.07",
#         "studentLed": false,
#         "numStudents": "20",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "3725.25",
#         "freeShipping": "true",
#         "teacherId": "109300",
#         "teacherName": "Ms. C.",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Garfield Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/garfield-elementary-school/4425/",
# ...
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "309.35",
#         "freeShipping": "true",
#         "teacherId": "3313295",
#         "teacherName": "Ms. Justis",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "San Miguel Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/san-miguel-elementary-school/4993/",
#         "city": "Sunnyvale",
#         "zip": "94085-3411",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.391807000000000",
#         "longitude": "-122.008140000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "28",
#           "name": "Nutrition Education",
#           "groupId": "2"
#         },
#         "additionalSubjects": [
#           {
#             "id": "23",
#             "name": "Special Needs",
#             "groupId": "7"
#           }
#         ],
#         "resource": {
#           "id": "15",
#           "name": "Educational Kits &amp; Games"
#         },
#         "expirationDate": "2018-04-08",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2859155",
#         "hashCode": "140170409",
#         "proposalURL": "https://www.donorschoose.org/project/empower-student-leaders-with-clifton-str/2859155/?verify=140170409&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2859155&donationAmount=45&verify=140170409&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1930076_sm.jpg?timestamp=1511909707604",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1930076_retina.jpg?timestamp=1511909707604",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1930076_thmb.jpg?timestamp=1511909707604",
#         "title": "Empower Student Leaders With Clifton Strengths Assessment Books",
#         "shortDescription": "My 8th grade W.E.B. (Where Everybody Belongs) Leadership students need your help to #FillEveryShelf with copies of the Clifton Strengths Finder book and assessment! Nominated by teachers for their...",
#         "fulfillmentTrailer": "My students need 36 individual copies of the book \"StrengthsFinder 2.0\" to assess their current individual strengths, and learn how to harness these unique leadership talents  effectively as emerging leaders.",
#         "snippets": [],
#         "percentFunded": "13",
#         "numDonors": "2",
#         "costToComplete": "694.95",
#         "studentLed": false,
#         "numStudents": "36",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "794.95",
#         "freeShipping": "true",
#         "teacherId": "1930076",
#         "teacherName": "Mr. Felicano",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Columbia Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/columbia-middle-school/4991/",
#         "city": "Sunnyvale",
#         "zip": "94085-3010",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.394165000000000",
#         "longitude": "-122.020149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "16",
#           "name": "College &amp; Career Prep",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "10",
#             "name": "Literacy",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "9",
#           "name": "Books"
#         },
#         "expirationDate": "2018-03-07",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2951548",
#         "hashCode": "1544873847",
#         "proposalURL": "https://www.donorschoose.org/project/ignite-their-learning/2951548/?verify=1544873847&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2951548&donationAmount=45&verify=1544873847&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1116694_sm.jpg?timestamp=1511931535032",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1116694_retina.jpg?timestamp=1511931535032",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1116694_thmb.jpg?timestamp=1511931535032",
#         "title": "Ignite Their Learning!",
#         "shortDescription": "My students come from a wide range of cultural, linguistic, and socioeconomic backgrounds. Fifty percent of my students are English Language Learners and need extra support in there language...",
#         "fulfillmentTrailer": "My students need laminating pouches and a laminator. Our materials are teacher-made and need to be protected for continued use. This is essential to protect the materials that have taken hours to prepare.",
#         "snippets": [],
#         "percentFunded": "14",
#         "numDonors": "1",
#         "costToComplete": "304.02",
#         "studentLed": false,
#         "numStudents": "500",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "354.02",
#         "freeShipping": "true",
#         "teacherId": "1116694",
#         "teacherName": "Mrs. Boostani",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 9,
#             "name": "NEA member"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Braly Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/braly-elementary-school/4963/",
#         "city": "Sunnyvale",
#         "zip": "94086-8016",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.364197000000000",
#         "longitude": "-122.017503000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "25",
#           "name": "ESL",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "10",
#             "name": "Literacy",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-03-29",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2911333",
#         "hashCode": "-905036549",
#         "proposalURL": "https://www.donorschoose.org/project/6th-graders-ready-for-hogwarts-school-of/2911333/?verify=-905036549&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2911333&donationAmount=45&verify=-905036549&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1930076_sm.jpg?timestamp=1511909707604",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1930076_retina.jpg?timestamp=1511909707604",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1930076_thmb.jpg?timestamp=1511909707604",
#         "title": "6th Graders Ready for Hogwarts School of Witchcraft and Wizardry",
#         "shortDescription": "My students are ready for their acceptance letters to join the magical world of Harry Potter, and all of the characters in the novels by J.K. Rowling! The magical adventures of Rowling's universe...",
#         "fulfillmentTrailer": "My students need copies of Harry Potter and the Sorcerer's Stone (plus 3 illustrated versions), and artifacts like the Sorting Hat, glasses, wands, and other items that bring the magic from the books to life!",
#         "snippets": [],
#         "percentFunded": "2",
#         "numDonors": "1",
#         "costToComplete": "1025.44",
#         "studentLed": false,
#         "numStudents": "65",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1045.44",
#         "freeShipping": "true",
#         "teacherId": "1930076",
#         "teacherName": "Mr. Felicano",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Columbia Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/columbia-middle-school/4991/",
#         "city": "Sunnyvale",
#         "zip": "94085-3010",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.394165000000000",
#         "longitude": "-122.020149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "9",
#           "name": "Books"
#         },
#         "expirationDate": "2018-03-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2786322",
#         "hashCode": "-255544637",
#         "proposalURL": "https://www.donorschoose.org/project/movement-makes-some-of-our-brains-work-b/2786322/?verify=-255544637&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2786322&donationAmount=45&verify=-255544637&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1141658_sm.jpg?timestamp=1445293965420",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1141658_retina.jpg?timestamp=1445293965420",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1141658_thmb.jpg?timestamp=1445293965420",
#         "title": "Movement Makes Some of Our Brains Work Better!",
#         "shortDescription": "I am excited to be the 5th grade classroom teacher. I have thirty-two excitable and intelligent 5th graders. These children come from the neighborhood surrounding my public school and travel here...",
#         "fulfillmentTrailer": "My students need wobble flexible chairs, balls, bands, and engaging seating options for the classroom!",
#         "snippets": [],
#         "percentFunded": "26",
#         "numDonors": "4",
#         "costToComplete": "671.92",
#         "studentLed": false,
#         "numStudents": "32",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "903.68",
#         "freeShipping": "true",
#         "teacherId": "1141658",
#         "teacherName": "Mrs. Jansen",
#         "gradeLevel": {
#           "id": "2",
#           "name": "Grades 3-5"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Ellis Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/ellis-elementary-school/4988/",
#         "city": "Sunnyvale",
#         "zip": "94086-6345",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.369736000000000",
#         "longitude": "-122.023701000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "27",
#           "name": "Health &amp; Wellness",
#           "groupId": "2"
#         },
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-20",
#         "fundingStatus": "needs funding"
#       }
#     ]
#   }
# }

# %%
city_data = {}

for cityname, data in all_data.items():
        
    #step 1: get cost to complete
    #step 2: get povertyType label
    #step 3: add this to the output vairable
    
    costcomplete = []
    povertytype = []
    
    data["proposals"]
    
    for x in data["proposals"]:
        
        costcomplete.append(float(x["costToComplete"]))
        povertytype.append(x["povertyType"]["label"])
    
    city_data[cityname] = {
        
        "costToComplete": sum(costcomplete),
        "povertyType": Counter(povertytype)
    }

city_data
# Out:
# {'San Anselmo': {'costToComplete': 0, 'povertyType': Counter()},
#  'San Bruno': {'costToComplete': 6750.049999999999,
#   'povertyType': Counter({'MODERATE': 1, 'MODERATELOW': 2})},
#  'San Carlos': {'costToComplete': 2020.91, 'povertyType': Counter({'LOW': 1})},
#  'San Francisco': {'costToComplete': 27881.14,
#   'povertyType': Counter({'HIGH': 16,
#            'HIGHEST': 13,
#            'MODERATE': 8,
#            'MODERATEHIGH': 11,
#            'MODERATELOW': 2})},
#  'San Jose': {'costToComplete': 28065.22,
#   'povertyType': Counter({'HIGH': 25,
#            'HIGHEST': 4,
#            'LOW': 3,
#            'MODERATE': 5,
#            'MODERATEHIGH': 10,
#            'MODERATELOW': 3})},
#  'San Leandro': {'costToComplete': 28936.22,
#   'povertyType': Counter({'HIGH': 2,
#            'HIGHEST': 4,
#            'MODERATEHIGH': 18,
#            'MODERATELOW': 3,
#            'UNKNOWN': 2})},
#  'San Mateo': {'costToComplete': 11393.52,
#   'povertyType': Counter({'MODERATE': 4,
#            'MODERATEHIGH': 3,
#            'MODERATELOW': 5})},
#  'San Pablo': {'costToComplete': 23074.489999999998,
#   'povertyType': Counter({'HIGH': 3,
#            'HIGHEST': 19,
#            'MODERATEHIGH': 2,
#            'UNKNOWN': 1})},
#  'San Rafael': {'costToComplete': 17090.54,
#   'povertyType': Counter({'HIGH': 7,
#            'HIGHEST': 8,
#            'LOW': 1,
#            'MODERATEHIGH': 2})},
#  'San Ramon': {'costToComplete': 48804.0, 'povertyType': Counter({'LOW': 46})},
#  'Santa Clara': {'costToComplete': 4951.839999999999,
#   'povertyType': Counter({'HIGH': 1,
#            'LOW': 1,
#            'MODERATE': 4,
#            'MODERATEHIGH': 2})},
#  'Santa Rosa': {'costToComplete': 18434.429999999997,
#   'povertyType': Counter({'HIGH': 10,
#            'HIGHEST': 7,
#            'LOW': 2,
#            'MODERATE': 4,
#            'MODERATEHIGH': 4})},
#  'Saratoga': {'costToComplete': 366.05, 'povertyType': Counter({'LOW': 2})},
#  'Sausalito': {'costToComplete': 572.65,
#   'povertyType': Counter({'MODERATE': 1})},
#  'Sebastopol': {'costToComplete': 621.67, 'povertyType': Counter({'LOW': 1})},
#  'Sonoma': {'costToComplete': 1449.3400000000001,
#   'povertyType': Counter({'MODERATE': 1, 'MODERATEHIGH': 1})},
#  'South San Francisco': {'costToComplete': 873.25,
#   'povertyType': Counter({'LOW': 1})},
#  'St. Helena': {'costToComplete': 0, 'povertyType': Counter()},
#  'Suisun City': {'costToComplete': 3787.85,
#   'povertyType': Counter({'HIGH': 1, 'MODERATEHIGH': 2})},
#  'Sunnyvale': {'costToComplete': 5864.740000000002,
#   'povertyType': Counter({'LOW': 1, 'MODERATEHIGH': 9, 'MODERATELOW': 2})}}

# %%
#list of cityname, costtocomplete, number of low, number of modeatelow, etc.

csv_data = []

citynames = sorted(city_data.keys())

for cityname in citynames: 
    
    data = city_data[cityname]
    
    one_row = []
    
    one_row.append(cityname)
    one_row.append(data['costToComplete'])  
    
    labeltype = ["LOW", "MODERATELOW", "MODERATE", "MODERATEHIGH", "HIGH", "HIGHEST", "UNKNOWN"]
    
    for x in labeltype:
        
        one_row.append(data['povertyType'].get(x, 0))
    
    csv_data.append(one_row)

csv_data
# Out:
# [['San Anselmo', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['San Bruno', 6750.049999999999, 0, 2, 1, 0, 0, 0, 0],
#  ['San Carlos', 2020.91, 1, 0, 0, 0, 0, 0, 0],
#  ['San Francisco', 27881.14, 0, 2, 8, 11, 16, 13, 0],
#  ['San Jose', 28065.22, 3, 3, 5, 10, 25, 4, 0],
#  ['San Leandro', 28936.22, 0, 3, 0, 18, 2, 4, 2],
#  ['San Mateo', 11393.52, 0, 5, 4, 3, 0, 0, 0],
#  ['San Pablo', 23074.489999999998, 0, 0, 0, 2, 3, 19, 1],
#  ['San Rafael', 17090.54, 1, 0, 0, 2, 7, 8, 0],
#  ['San Ramon', 48804.0, 46, 0, 0, 0, 0, 0, 0],
#  ['Santa Clara', 4951.839999999999, 1, 0, 4, 2, 1, 0, 0],
#  ['Santa Rosa', 18434.429999999997, 2, 0, 4, 4, 10, 7, 0],
#  ['Saratoga', 366.05, 2, 0, 0, 0, 0, 0, 0],
#  ['Sausalito', 572.65, 0, 0, 1, 0, 0, 0, 0],
#  ['Sebastopol', 621.67, 1, 0, 0, 0, 0, 0, 0],
#  ['Sonoma', 1449.3400000000001, 0, 0, 1, 1, 0, 0, 0],
#  ['South San Francisco', 873.25, 1, 0, 0, 0, 0, 0, 0],
#  ['St. Helena', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Suisun City', 3787.85, 0, 0, 0, 2, 1, 0, 0],
#  ['Sunnyvale', 5864.740000000002, 1, 2, 0, 9, 0, 0, 0]]

# %%
root_path = os.path.join(os.getcwd())
data_path = os.path.join(root_path)
csvpath = os.path.join(root_path, "donorschoose_api.csv")
with open(csvpath, "a", newline="") as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=",")
    csvwriter.writerows(csv_data)
