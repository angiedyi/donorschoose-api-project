# %%
import csv
import os
import requests as req
import json
from collections import Counter

# %%
#Donorschoose.org API
api_key = "DONORSCHOOSE"
url = "https://api.donorschoose.org/common/json_feed.html?max=100"

# %%
#Open a CSV for a list of Bay Area cities
with open("bayarea_cities.csv") as cities:
    cities_reader = csv.reader(cities)
    
    cities = [city[0] for city in cities_reader]
    
    print(len(cities))

cities = cities[22:39]
print(cities)
# Out:
# 102
# ['Daly City', 'Danville', 'Dixon', 'Dublin', 'East Palo Alto', 'El Cerrito', 'Emeryville', 'Fairfax', 'Fairfield', 'Foster City', 'Fremont', 'Gilroy', 'Half Moon Bay', 'Hayward', 'Healdsburg', 'Hercules', 'Hillsborough']

# %%
# Build partial query URL
query_url = url + "&APIkey=" + api_key + "&state=CA" + "&cityName="
#location_data = [req.get(query_url + city).json() for city in cities]

all_data = {}

for city in cities:
    
    results = req.get(query_url + city).json()
    all_data[city] = results   

print(json.dumps(all_data, indent=2))
# Out:
# {
#   "Daly City": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=Daly+City&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "17",
#     "index": "0",
#     "max": "17",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": [
#       {
#         "id": "2952286",
#         "hashCode": "480458329",
#         "proposalURL": "https://www.donorschoose.org/project/keeping-educational-videos-accessible/2952286/?verify=480458329&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2952286&donationAmount=45&verify=480458329&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u99075_sm.jpg?timestamp=1505760967229",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u99075_retina.jpg?timestamp=1505760967229",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u99075_thmb.jpg?timestamp=1505760967229",
#         "title": "Keeping Educational Videos Accessible",
#         "shortDescription": "I teach English Langauge Development and Guided Reading at a wonderful Title I elementary school in Northern California. My Title I students are from low socioeconomic backgrounds and most receive...",
#         "fulfillmentTrailer": "My students need external DVD drives so we can continue to watch the educational DVDs available.  We also need ink cartridges to keep our printer running.",
#         "snippets": [],
#         "percentFunded": "43",
#         "numDonors": "1",
#         "costToComplete": "96.40",
#         "studentLed": false,
#         "numStudents": "99",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "169.34",
#         "freeShipping": "true",
#         "teacherId": "99075",
#         "teacherName": "Ms. Dineen",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "25",
#           "name": "ESL",
#           "groupId": "6"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "7",
#           "name": "Computers &amp; Tablets"
#         },
#         "expirationDate": "2018-03-29",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2909077",
#         "hashCode": "159377451",
#         "proposalURL": "https://www.donorschoose.org/project/bring-my-crazy-animal-lovers-to-the-zoo/2909077/?verify=159377451&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2909077&donationAmount=45&verify=159377451&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u2431126_sm.jpg?timestamp=1471905378105",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u2431126_retina.jpg?timestamp=1471905378105",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u2431126_thmb.jpg?timestamp=1471905378105",
#         "title": "Bring My Crazy Animal Lovers to the Zoo!",
#         "shortDescription": "I am a teacher of a classroom of students with different abilities. I have seven students who are diagnosed with Autism. They are all clever, happy boys and love learning about the world around...",
#         "fulfillmentTrailer": "My students need to get out in their community and visit places like the zoo!",
#         "snippets": [],
#         "percentFunded": "48",
#         "numDonors": "7",
#         "costToComplete": "426.25",
#         "studentLed": false,
#         "numStudents": "50",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "GENENTECH_18",
#           "ownerRegion": "",
#           "name": "Genentech, Inc.",
#           "donorSalutation": "Genentech, Inc.",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/genentech_135.gif",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=GENENTECH_18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/genentech_135.gif\"></p>\r\n<p>Donations to this project are now being matched, thanks to support from Genentech. </p>\r\n<p>Futurelab is Genentech\u2019s hyper-local STEM education initiative that supports all K-12 students in the South San Francisco Unified School District (SSFUSD), gets them excited to learn about science, promotes hands-on learning, improves their college readiness and inspires them to pursue careers in STEM fields. Genentech is proud to support the community where we\u2019ve been based for over 40 years through funding, employee time and talent, and material donations.</p>\r\n<p>For more information, please visit <a target=\"_blank\" href=\"https://www.gene.com/good/science-education\">Futurelab.</a></p>\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1251\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "816.25",
#         "freeShipping": "true",
#         "teacherId": "2431126",
#         "teacherName": "Ms. Kenton",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "",
#         "povertyType": {
#           "label": "LOW",
#           "name": "",
#           "range": "0%-30%",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Junipero Serra Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/junipero-serra-elementary-school/4654/",
#         "city": "Daly City",
#         "zip": "94015-2799",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.660301000000000",
#         "longitude": "-122.469208000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "4",
#           "name": "Health &amp; Life Science",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "23",
#             "name": "Special Needs",
#             "groupId": "7"
#           }
#         ],
#         "resource": {
#           "id": "4",
#           "name": "Trips"
#         },
#         "expirationDate": "2018-03-21",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2915186",
#         "hashCode": "-1969448952",
#         "proposalURL": "https://www.donorschoose.org/project/keeping-organized-and-cozy-in-kinder/2915186/?verify=-1969448952&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2915186&donationAmount=45&verify=-1969448952&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1725761_sm.jpg?timestamp=1476227691552",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1725761_retina.jpg?timestamp=1476227691552",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1725761_thmb.jpg?timestamp=1476227691552",
#         "title": "Keeping Organized and Cozy in Kinder",
#         "shortDescription": "We have a wonderful group of students that are always ready and excited to learn! Many of them come from various socioeconomic backgrounds and cultures, but we all come together in our classroom...",
#         "fulfillmentTrailer": "My students need organization materials and comfort in the classroom to have a well-suited environment for learning!",
#         "snippets": [],
#         "percentFunded": "81",
#         "numDonors": "2",
#         "costToComplete": "255.45",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1334.45",
#         "freeShipping": "true",
#         "teacherId": "1725761",
#         "teacherName": "Ms. Haining",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than three\u2011quarters of students from low\u2011income households",
#         "povertyType": {
#           "label": "HIGH",
#           "name": "More than three\u2011quarters of students from low\u2011income households",
#           "range": "76-89%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "W Wilson Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/w-wilson-elementary-school/4537/",
#         "city": "Daly City",
#         "zip": "94014-3814",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.703960000000000",
#         "longitude": "-122.464760000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "18",
#           "name": "Early Development",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "3",
#             "name": "Literature &amp; Writing",
#             "groupId": "6"
#           }
#         ],
#         "resource": {
#           "id": "13",
#           "name": "Reading Nooks, Desks &amp; Storage"
#         },
#         "expirationDate": "2018-03-27",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2930769",
#         "hashCode": "-1894828825",
#         "proposalURL": "https://www.donorschoose.org/project/cant-stop-the-feeling-help-me-learn-w/2930769/?verify=-1894828825&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2930769&donationAmount=45&verify=-1894828825&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u2578008_sm.jpg?timestamp=1470029211166",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u2578008_retina.jpg?timestamp=1470029211166",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u2578008_thmb.jpg?timestamp=1470029211166",
#         "title": "Can&#039;t Stop The Feeling! (Help Me Learn What It Is)",
#         "shortDescription": "I work at a Title I school right outside San Francisco with five special day classes with students in preschool to 4th grade. My students are a fun bunch of diverse kids who love school and enjoy...",
#         "fulfillmentTrailer": "My students need books and materials for activities that will help them learn how to identify their feelings and the feelings of others.",
#         "snippets": [],
#         "percentFunded": "8",
#         "numDonors": "2",
#         "costToComplete": "323.11",
#         "studentLed": false,
#         "numStudents": "40",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "BTW_18",
#           "ownerRegion": "",
#           "name": "Born This Way Foundation",
#           "donorSalutation": "Born This Way Foundation",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/bornthisway_250.png",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=BTW_18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/bornthisway_250.png\"></p>\r\n<p>Donations to this project are now being matched, thanks to support from Born This Way Foundation.</p>\r\n<p> Co-founded by Lady Gaga and her mother, Cynthia Germanotta, the foundation supports the wellness of young people and empowers them to create a kinder, braver world by fostering kinder communities, improved mental health resources, and more positive environments \u2014online and offline.</p>\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1319\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "353.11",
#         "freeShipping": "false",
#         "teacherId": "2578008",
#         "teacherName": "Ms. Reves",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "26",
#           "name": "Character Education",
#           "groupId": "5"
#         },
#         "additionalSubjects": [
#           {
#             "id": "23",
#             "name": "Special Needs",
#             "groupId": "7"
#           }
#         ],
#         "resource": {
#           "id": "9",
#           "name": "Books"
#         },
#         "expirationDate": "2018-04-06",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2793337",
#         "hashCode": "1910597162",
#         "proposalURL": "https://www.donorschoose.org/project/creating-learning-and-appreciating-musi/2793337/?verify=1910597162&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2793337&donationAmount=45&verify=1910597162&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u4697030_sm.jpg?timestamp=1504214866988",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u4697030_retina.jpg?timestamp=1504214866988",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u4697030_thmb.jpg?timestamp=1504214866988",
#         "title": "Creating, Learning and Appreciating Music with the Ukulele.",
#         "shortDescription": "Our classroom is very special. There are two teachers, Ms. Lum and Mrs. Tucciarone, who share in the joy of seeing the children come into the classroom each day full of excitement, curiosity and...",
#         "fulfillmentTrailer": "My students need Ukuleles and an opportunity to learn the joys of creating music.",
#         "snippets": [],
#         "percentFunded": "43",
#         "numDonors": "5",
#         "costToComplete": "574.78",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1004.78",
#         "freeShipping": "true",
#         "teacherId": "4697030",
#         "teacherName": "Ms. Lum",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           }
#         ],
#         "schoolName": "Skyline Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/skyline-elementary-school/4648/",
#         "city": "Daly City",
#         "zip": "94015-2899",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.651661000000000",
#         "longitude": "-122.465378000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "1",
#           "name": "Performing Arts",
#           "groupId": "1"
#         },
#         "additionalSubjects": [
#           {
#             "id": "12",
#             "name": "Music",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-14",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2970794",
#         "hashCode": "-1573751131",
#         "proposalURL": "https://www.donorschoose.org/project/special-education-basics/2970794/?verify=-1573751131&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2970794&donationAmount=45&verify=-1573751131&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u2578008_sm.jpg?timestamp=1470029211166",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u2578008_retina.jpg?timestamp=1470029211166",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u2578008_thmb.jpg?timestamp=1470029211166",
#         "title": "Special Education Basics.",
#         "shortDescription": "I work at a Title I school right outside San Francisco with five special day classes with students in preschool to 4th grade. My students are a fun bunch of diverse kids who love school and enjoy...",
#         "fulfillmentTrailer": "My students need Velcro, laminating pouches, cardstock and a new classroom timer to help implement our special education curriculum.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "411.34",
#         "studentLed": false,
#         "numStudents": "40",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "QUILL18_2",
#           "ownerRegion": "",
#           "name": "Quill.com",
#           "donorSalutation": "Quill.com",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/quill_250.jpg",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=QUILL18_2",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/quill_250.jpg\"></p>\r\n\r\n<p>Donations to this project are now being matched, thanks to support from Quill.com. </p>\r\n\r\n<p>Because Quill.com understands schools, Quill.com offers a variety of tailored programs and services to meet their needs. By actively partnering with national organizations like DonorsChoose.org, Quill.com helps schools enrich learning by ensuring low prices on the supplies classrooms need most.</p>\r\n\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1334\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "411.34",
#         "freeShipping": "true",
#         "teacherId": "2578008",
#         "teacherName": "Ms. Reves",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "23",
#           "name": "Special Needs",
#           "groupId": "7"
#         },
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-04-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2780090",
#         "hashCode": "-1357269397",
#         "proposalURL": "https://www.donorschoose.org/project/kids-at-play/2780090/?verify=-1357269397&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2780090&donationAmount=45&verify=-1357269397&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u117410_sm.jpg?timestamp=1294107674000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u117410_retina.jpg?timestamp=1294107674000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u117410_thmb.jpg?timestamp=1294107674000",
#         "title": "Kids at Play",
#         "shortDescription": "My students are from a high poverty neighborhood who face more challenges than the average student. Even though they may be at a disadvantage, these students are hard working, determined students...",
#         "fulfillmentTrailer": "My students need water play table, a top for the water play table, set of soft and safe bean bags, play dough, and dough letter stampers.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "463.52",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "FITNESS18",
#           "ownerRegion": "",
#           "name": "National Fitness Foundation",
#           "donorSalutation": "National Fitness Foundation",
#           "type": "AUTO_DONATION_MATCH",
#           "matchImpactMultiple": 2,
#           "multipleForDisplay": "2X",
#           "logoURL": "https://cdn.donorschoose.net/images/logos/nff_250.png",
#           "faqURL": "https://www.donorschoose.org/donors/matching_grant_popup.html?matchingKey=FITNESS18",
#           "amount": "0.00",
#           "description": "<p align=\"center\"><img src=\"https://cdn.donorschoose.net/images/logos/nff_250.png\"></p>\r\n\r\n<p>Donations to this project are now being matched, thanks to support from National Fitness Foundation. The National Fitness Foundation is on a mission to prepare children for a lifetime of health & fitness.</p>\r\n\r\n<p>Through prioritizing quality physical education, the most inclusive, evidence-based solution to get kids active, and providing resources, grants and professional development to physical educators, we are helping students perform at their highest potential inside and outside the classroom.</p>\r\n\r\n<p>By supporting the  <a href=\"https://help.donorschoose.org/hc/en-us/articles/115014079587\" target=\"_blank\"> PE innovation Challenge</a>, you can lift up the creative work of physical educators and empower students to be healthy and active for life.</p>\r\n\r\n<p><a target=\"_blank\" href=\"../donors/search.html?matchingId=1314\">See all projects eligible for this match offer.</a></p>"
#         },
#         "totalPrice": "463.52",
#         "freeShipping": "true",
#         "teacherId": "117410",
#         "teacherName": "Mrs. Vizcarra",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "27",
#           "name": "Health &amp; Wellness",
#           "groupId": "2"
#         },
#         "additionalSubjects": [
#           {
#             "id": "29",
#             "name": "Gym &amp; Fitness",
#             "groupId": "2"
#           }
#         ],
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2720023",
#         "hashCode": "1552183907",
#         "proposalURL": "https://www.donorschoose.org/project/ready-art-action/2720023/?verify=1552183907&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2720023&donationAmount=45&verify=1552183907&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u1521381_sm.jpg?timestamp=1498678732901",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u1521381_retina.jpg?timestamp=1498678732901",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u1521381_thmb.jpg?timestamp=1498678732901",
#         "title": "Ready, Art, Action!",
#         "shortDescription": "As a teacher at a diverse school where classrooms are full of students varying in language and academic backgrounds, I try to really get to know and connect with each student even if it means...",
#         "fulfillmentTrailer": "My students need a laminator to preserve art projects created throughout the school year for our district wide art fair and for lifetime keepsakes.",
#         "snippets": [],
#         "percentFunded": "31",
#         "numDonors": "10",
#         "costToComplete": "1329.20",
#         "studentLed": false,
#         "numStudents": "430",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1926.26",
#         "freeShipping": "true",
#         "teacherId": "1521381",
#         "teacherName": "Ms. Beauchemin",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Daniel Webster Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/daniel-webster-elementary-school/4527/",
#         "city": "Daly City",
#         "zip": "94015-2199",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.677659000000000",
#         "longitude": "-122.477908000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "11",
#           "name": "Visual Arts",
#           "groupId": "1"
#         },
#         "additionalSubjects": [
#           {
#             "id": "12",
#             "name": "Music",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2017-12-22",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2779977",
#         "hashCode": "-1357269510",
#         "proposalURL": "https://www.donorschoose.org/project/art-for-arts-sake/2779977/?verify=-1357269510&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2779977&donationAmount=45&verify=-1357269510&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u117410_sm.jpg?timestamp=1294107674000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u117410_retina.jpg?timestamp=1294107674000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u117410_thmb.jpg?timestamp=1294107674000",
#         "title": "Art for Art&#039;s Sake",
#         "shortDescription": "My students are from a high poverty neighborhood who face more challenges than the average student. Even though they may be at a disadvantage, these students are hard working, determined students...",
#         "fulfillmentTrailer": "My students need paint, paint brushes, dot markers, scissors, and ink pads.",
#         "snippets": [],
#         "percentFunded": "9",
#         "numDonors": "1",
#         "costToComplete": "251.61",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "276.61",
#         "freeShipping": "true",
#         "teacherId": "117410",
#         "teacherName": "Mrs. Vizcarra",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "11",
#           "name": "Visual Arts",
#           "groupId": "1"
#         },
#         "resource": {
#           "id": "3",
#           "name": "Supplies"
#         },
#         "expirationDate": "2018-01-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2915260",
#         "hashCode": "-1969448878",
#         "proposalURL": "https://www.donorschoose.org/project/flexible-seating/2915260/?verify=-1969448878&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2915260&donationAmount=45&verify=-1969448878&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u2768648_sm.jpg?timestamp=1479245815710",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u2768648_retina.jpg?timestamp=1479245815710",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u2768648_thmb.jpg?timestamp=1479245815710",
#         "title": "Flexible Seating",
#         "shortDescription": "I have a great group of students this year. They are enthusiastic. They work hard and are very sweet and caring! <br />They've been together for a few of years now and have developed their own little...",
#         "fulfillmentTrailer": "My students need options for flexible seating while working in the classroom.",
#         "snippets": [],
#         "percentFunded": "27",
#         "numDonors": "3",
#         "costToComplete": "257.74",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "352.74",
#         "freeShipping": "true",
#         "teacherId": "2768648",
#         "teacherName": "Ms. Kotoff",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "Half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATE",
#           "name": "Half of students from low\u2011income households",
#           "range": "45-54%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [
#           {
#             "id": 3,
#             "name": "Special Education"
#           },
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           },
#           {
#             "id": 14,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "Thomas Edison Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/thomas-edison-elementary-school/4534/",
#         "city": "Daly City",
#         "zip": "94015-3998",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.676308000000000",
#         "longitude": "-122.485598000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "27",
#           "name": "Health &amp; Wellness",
#           "groupId": "2"
#         },
#         "additionalSubjects": [
#           {
#             "id": "23",
#             "name": "Special Needs",
#             "groupId": "7"
#           }
#         ],
#         "resource": {
#           "id": "12",
#           "name": "Flexible Seating"
#         },
#         "expirationDate": "2018-03-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2780018",
#         "hashCode": "-1357269469",
#         "proposalURL": "https://www.donorschoose.org/project/reading-feeds-the-imagination/2780018/?verify=-1357269469&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2780018&donationAmount=45&verify=-1357269469&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u117410_sm.jpg?timestamp=1294107674000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u117410_retina.jpg?timestamp=1294107674000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u117410_thmb.jpg?timestamp=1294107674000",
#         "title": "Reading Feeds the Imagination!",
#         "shortDescription": "My students are from a high poverty neighborhood who face more challenges than the average student. Even though they may be at a disadvantage, these students are hard working, determined students...",
#         "fulfillmentTrailer": "My students need leveled and fairy tales read along books with CDs.",
#         "snippets": [],
#         "percentFunded": "21",
#         "numDonors": "2",
#         "costToComplete": "404.34",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "514.34",
#         "freeShipping": "true",
#         "teacherId": "117410",
#         "teacherName": "Mrs. Vizcarra",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "resource": {
#           "id": "1",
#           "name": "Books"
#         },
#         "expirationDate": "2018-01-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2780050",
#         "hashCode": "-1357269437",
#         "proposalURL": "https://www.donorschoose.org/project/to-succeed-you-must-read/2780050/?verify=-1357269437&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2780050&donationAmount=45&verify=-1357269437&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u117410_sm.jpg?timestamp=1294107674000",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u117410_retina.jpg?timestamp=1294107674000",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u117410_thmb.jpg?timestamp=1294107674000",
#         "title": "To Succeed, You Must Read!",
#         "shortDescription": "My students are from a high poverty neighborhood who face more challenges than the average student. Even though they may be at a disadvantage, these students are hard working, determined students...",
#         "fulfillmentTrailer": "My students need several Big Books that we can add to our library.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "272.07",
#         "studentLed": false,
#         "numStudents": "24",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "272.07",
#         "freeShipping": "true",
#         "teacherId": "117410",
#         "teacherName": "Mrs. Vizcarra",
#         "gradeLevel": {
#           "id": "1",
#           "name": "Grades PreK-2"
#         },
#         "povertyLevel": "More than half of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATEHIGH",
#           "name": "More than half of students from low\u2011income households",
#           "range": "55-75%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [
#           {
#             "id": 11,
#             "name": "U.S. Cellular teacher"
#           },
#           {
#             "id": 5,
#             "name": "SONIC Teacher"
#           }
#         ],
#         "schoolTypes": [
#           {
#             "id": 15,
#             "name": "Kia (partner)"
#           }
#         ],
#         "schoolName": "John F Kennedy Elementary School",
#         "schoolUrl": "https://www.donorschoose.org/school/j-f-kennedy-elementary-school/4532/",
#         "city": "Daly City",
#         "zip": "94014-2163",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "37.694475000000000",
#         "longitude": "-122.455149000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "10",
#           "name": "Literacy",
#           "groupId": "6"
#         },
#         "resource": {
#           "id": "1",
#           "name": "Books"
#         },
#         "expirationDate": "2018-01-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2795358",
#         "hashCode": "846182927",
#         "proposalURL": "https://www.donorschoose.org/project/swimming-with-disneynatures-dolphins/2795358/?verify=846182927&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2795358&donationAmount=45&verify=846182927&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u23933_sm.jpg?timestamp=1508185763628",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u23933_retina.jpg?timestamp=1508185763628",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u23933_thmb.jpg?timestamp=1508185763628",
#         "title": "Swimming With Disneynature&#039;s Dolphins!",
#         "shortDescription": "The 58 eyes and 58 ears that are waiting to be filled with great stories, tales, adventures, and knowledge are a classroom of curious, question-asking, adventure-seeking nine and ten year olds...",
#         "fulfillmentTrailer": "My students need tickets to see Disneynature's Dolphins to celebrate Earth Day 2018!",
#         "snippets": [],
#         "percentFunded": "17",
#         "numDonors": "2",
#         "costToComplete": "472.65",
#         "studentLed": false,
#         "numStudents": "85",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
# ...
#         "title": "Go Pro and Enjoy Learning Science",
#         "shortDescription": "The majority of my students are below proficiency in language arts, science, and math. Thirty-five percent of students enrolled are economically disadvantaged. With the economic problems our...",
#         "fulfillmentTrailer": "My students need go pro and mini iPad to be science effective and efficient.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "1268.15",
#         "studentLed": false,
#         "numStudents": "175",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1268.15",
#         "freeShipping": "true",
#         "teacherId": "481483",
#         "teacherName": "Mrs. Gatchalian",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Hercules High School",
#         "schoolUrl": "https://www.donorschoose.org/school/hercules-middle-high-school/4193/",
#         "city": "Hercules",
#         "zip": "94547-1554",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.000706000000000",
#         "longitude": "-122.254340000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "6",
#           "name": "Applied Sciences",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "16",
#             "name": "College &amp; Career Prep",
#             "groupId": "5"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-03",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2724829",
#         "hashCode": "1686715022",
#         "proposalURL": "https://www.donorschoose.org/project/smart-collaboration/2724829/?verify=1686715022&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2724829&donationAmount=45&verify=1686715022&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u435086_sm.jpg?timestamp=1440377511201",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u435086_retina.jpg?timestamp=1440377511201",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u435086_thmb.jpg?timestamp=1440377511201",
#         "title": "SMART Collaboration",
#         "shortDescription": "\"The essence of mathematics is not to make simple things complicated but to make complicated things simple.\" -S. Gadder. <br />My STEM and Math classes continue to inspire me as a teacher. I teach one...",
#         "fulfillmentTrailer": "My students need SMART Kapp to enhance collaborative learning process and improve students\u2019 engagement in learning experiences.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "1596.11",
#         "studentLed": false,
#         "numStudents": "163",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1596.11",
#         "freeShipping": "true",
#         "teacherId": "435086",
#         "teacherName": "Mrs. Cruzat",
#         "gradeLevel": {
#           "id": "4",
#           "name": "Grades 9-12"
#         },
#         "povertyLevel": "More than a third of students from low\u2011income households",
#         "povertyType": {
#           "label": "MODERATELOW",
#           "name": "More than a third of students from low\u2011income households",
#           "range": "30-44%",
#           "showPovertyLevel": "true"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Hercules High School",
#         "schoolUrl": "https://www.donorschoose.org/school/hercules-middle-high-school/4193/",
#         "city": "Hercules",
#         "zip": "94547-1554",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.000706000000000",
#         "longitude": "-122.254340000000000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "8",
#           "name": "Mathematics",
#           "groupId": "4"
#         },
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-01",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2915220",
#         "hashCode": "-1969448918",
#         "proposalURL": "https://www.donorschoose.org/project/wheres-the-film-equipment-for-film-clas/2915220/?verify=-1969448918&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2915220&donationAmount=45&verify=-1969448918&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3250568_sm.jpg?timestamp=1505253844423",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3250568_retina.jpg?timestamp=1505253844423",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3250568_thmb.jpg?timestamp=1505253844423",
#         "title": "Where&#039;s the Film Equipment for Film Class?",
#         "shortDescription": "Students here represent a wide variety of cultures, ethnic groups, orientations, religions, and genders. The entire campus has over 600 students from neighborhoods throughout East Bay from...",
#         "fulfillmentTrailer": "My students need equipment including a camcorder with tripod and LED Panel Light, we're running on barely any materials. Our current cameras are student owned cell phones and tablets which keeps some students from participating.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "465.13",
#         "studentLed": false,
#         "numStudents": "30",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "465.13",
#         "freeShipping": "true",
#         "teacherId": "3250568",
#         "teacherName": "Mr. Owens",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "Data Unavailable",
#         "povertyType": {
#           "label": "UNKNOWN",
#           "name": "Data unavailable",
#           "range": "Data unavailable",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Hercules Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/hercules-middle-school/121330/",
#         "city": "Hercules",
#         "zip": "94547-1554",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.000737050314500",
#         "longitude": "-122.254070425285000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "1",
#           "name": "Performing Arts",
#           "groupId": "1"
#         },
#         "additionalSubjects": [
#           {
#             "id": "11",
#             "name": "Visual Arts",
#             "groupId": "1"
#           }
#         ],
#         "resource": {
#           "id": "8",
#           "name": "Instructional Technology"
#         },
#         "expirationDate": "2018-03-09",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2793363",
#         "hashCode": "1910597188",
#         "proposalURL": "https://www.donorschoose.org/project/mac-for-science-and-technology/2793363/?verify=1910597188&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2793363&donationAmount=45&verify=1910597188&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3375488_sm.jpg?timestamp=1451074351394",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3375488_retina.jpg?timestamp=1451074351394",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3375488_thmb.jpg?timestamp=1451074351394",
#         "title": "Mac for Science and Technology",
#         "shortDescription": "We have a very diverse group here in the Bay Area. All the races are learning together in a very affluent setting. Though many students are from poorer homes, they all somehow look and act...",
#         "fulfillmentTrailer": "My students need to see what a Mac looks and acts like! There are a variety of features to share with the class about these professional computers.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "0",
#         "costToComplete": "1412.56",
#         "studentLed": false,
#         "numStudents": "200",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "1412.56",
#         "freeShipping": "true",
#         "teacherId": "3375488",
#         "teacherName": "Mr. S.",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "Data Unavailable",
#         "povertyType": {
#           "label": "UNKNOWN",
#           "name": "Data unavailable",
#           "range": "Data unavailable",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Hercules Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/hercules-middle-school/121330/",
#         "city": "Hercules",
#         "zip": "94547-1554",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.000737050314500",
#         "longitude": "-122.254070425285000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "7",
#           "name": "Environmental Science",
#           "groupId": "4"
#         },
#         "additionalSubjects": [
#           {
#             "id": "6",
#             "name": "Applied Sciences",
#             "groupId": "4"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-14",
#         "fundingStatus": "needs funding"
#       },
#       {
#         "id": "2785557",
#         "hashCode": "-255545402",
#         "proposalURL": "https://www.donorschoose.org/project/school-wide-broadcasting/2785557/?verify=-255545402&utm_source=api&utm_medium=feed&utm_content=bodylink&utm_campaign=DONORSCHOOSE",
#         "fundURL": "https://secure.donorschoose.org/donors/givingCart.html?proposalid=2785557&donationAmount=45&verify=-255545402&utm_source=api&utm_medium=feed&utm_content=fundlink&utm_campaign=DONORSCHOOSE",
#         "imageURL": "https://storage.donorschoose.net/dc_prod/images/user/small/u3250568_sm.jpg?timestamp=1505253844423",
#         "retinaImageURL": "https://storage.donorschoose.net/dc_prod/images/user/retina/u3250568_retina.jpg?timestamp=1505253844423",
#         "thumbImageURL": "https://storage.donorschoose.net/dc_prod/images/user/thumbnail/u3250568_thmb.jpg?timestamp=1505253844423",
#         "title": "School-Wide Broadcasting!",
#         "shortDescription": "Students here represent a wide variety of cultures, ethnic groups, orientations, religions, and genders. The entire campus has over 600 students from neighborhoods throughout East Bay from...",
#         "fulfillmentTrailer": "My students need TVs for school announcements/educator films and a scanner to check out materials.",
#         "snippets": [],
#         "percentFunded": "0",
#         "numDonors": "1",
#         "costToComplete": "9081.87",
#         "studentLed": false,
#         "numStudents": "602",
#         "professionalDevelopment": false,
#         "matchingFund": {
#           "matchingKey": "",
#           "ownerRegion": "",
#           "name": "",
#           "donorSalutation": "",
#           "type": "",
#           "matchImpactMultiple": "",
#           "multipleForDisplay": "",
#           "logoURL": "",
#           "faqURL": "",
#           "amount": "0.00",
#           "description": ""
#         },
#         "totalPrice": "9101.87",
#         "freeShipping": "true",
#         "teacherId": "3250568",
#         "teacherName": "Mr. Owens",
#         "gradeLevel": {
#           "id": "3",
#           "name": "Grades 6-8"
#         },
#         "povertyLevel": "Data Unavailable",
#         "povertyType": {
#           "label": "UNKNOWN",
#           "name": "Data unavailable",
#           "range": "Data unavailable",
#           "showPovertyLevel": "false"
#         },
#         "teacherTypes": [],
#         "schoolTypes": [],
#         "schoolName": "Hercules Middle School",
#         "schoolUrl": "https://www.donorschoose.org/school/hercules-middle-school/121330/",
#         "city": "Hercules",
#         "zip": "94547-1554",
#         "state": "CA",
#         "stateFullName": "California",
#         "latitude": "38.000737050314500",
#         "longitude": "-122.254070425285000",
#         "zone": {
#           "id": "402",
#           "name": "California (North)"
#         },
#         "subject": {
#           "id": "11",
#           "name": "Visual Arts",
#           "groupId": "1"
#         },
#         "additionalSubjects": [
#           {
#             "id": "16",
#             "name": "College &amp; Career Prep",
#             "groupId": "5"
#           }
#         ],
#         "resource": {
#           "id": "2",
#           "name": "Technology"
#         },
#         "expirationDate": "2018-01-12",
#         "fundingStatus": "needs funding"
#       }
#     ]
#   },
#   "Hillsborough": {
#     "searchTerms": "CA",
#     "searchURL": "https://www.donorschoose.org/donors/search.html?APIkey=DONORSCHOOSE&cityName=Hillsborough&state=CA&utm_source=api&utm_medium=feed&utm_content=searchlink&utm_campaign=DONORSCHOOSE",
#     "totalProposals": "0",
#     "index": "0",
#     "max": "50",
#     "breadcrumb": [
#       [
#         "max",
#         "100",
#         ""
#       ],
#       [
#         "state",
#         "CA",
#         "California"
#       ]
#     ],
#     "proposals": []
#   }
# }

# %%
city_data = {}

for cityname, data in all_data.items():
        
    #step 1: get cost to complete
    #step 2: get povertyType label
    #step 3: add this to the output vairable
    
    costcomplete = []
    povertytype = []
    
    data["proposals"]
    
    for x in data["proposals"]:
        
        costcomplete.append(float(x["costToComplete"]))
        povertytype.append(x["povertyType"]["label"])
    
    city_data[cityname] = {
        
        "costToComplete": sum(costcomplete),
        "povertyType": Counter(povertytype)
    }

city_data
# Out:
# {'Daly City': {'costToComplete': 8266.81,
#   'povertyType': Counter({'HIGH': 1,
#            'LOW': 1,
#            'MODERATE': 1,
#            'MODERATEHIGH': 13,
#            'MODERATELOW': 1})},
#  'Danville': {'costToComplete': 30718.34, 'povertyType': Counter({'LOW': 20})},
#  'Dixon': {'costToComplete': 1096.23,
#   'povertyType': Counter({'MODERATE': 1, 'MODERATELOW': 1})},
#  'Dublin': {'costToComplete': 16169.74, 'povertyType': Counter({'LOW': 19})},
#  'East Palo Alto': {'costToComplete': 21437.47,
#   'povertyType': Counter({'HIGHEST': 23})},
#  'El Cerrito': {'costToComplete': 9935.399999999998,
#   'povertyType': Counter({'LOW': 4, 'MODERATEHIGH': 8, 'MODERATELOW': 3})},
#  'Emeryville': {'costToComplete': 994.62,
#   'povertyType': Counter({'MODERATEHIGH': 1})},
#  'Fairfax': {'costToComplete': 454.82, 'povertyType': Counter({'LOW': 1})},
#  'Fairfield': {'costToComplete': 27023.86,
#   'povertyType': Counter({'HIGHEST': 15,
#            'MODERATEHIGH': 2,
#            'MODERATELOW': 16})},
#  'Foster City': {'costToComplete': 0, 'povertyType': Counter()},
#  'Fremont': {'costToComplete': 34197.53,
#   'povertyType': Counter({'LOW': 41,
#            'MODERATE': 3,
#            'MODERATEHIGH': 1,
#            'MODERATELOW': 5})},
#  'Gilroy': {'costToComplete': 9405.53,
#   'povertyType': Counter({'HIGH': 1,
#            'MODERATE': 8,
#            'MODERATEHIGH': 2,
#            'MODERATELOW': 3})},
#  'Half Moon Bay': {'costToComplete': 0, 'povertyType': Counter()},
#  'Hayward': {'costToComplete': 34049.53,
#   'povertyType': Counter({'HIGH': 11,
#            'MODERATE': 1,
#            'MODERATEHIGH': 37,
#            'MODERATELOW': 1})},
#  'Healdsburg': {'costToComplete': 0, 'povertyType': Counter()},
#  'Hercules': {'costToComplete': 16210.6,
#   'povertyType': Counter({'MODERATELOW': 6, 'UNKNOWN': 3})},
#  'Hillsborough': {'costToComplete': 0, 'povertyType': Counter()}}

# %%
#list of cityname, costtocomplete, number of low, number of modeatelow, etc.

csv_data = []

citynames = sorted(city_data.keys())

for cityname in citynames: 
    
    data = city_data[cityname]
    
    one_row = []
    
    one_row.append(cityname)
    one_row.append(data['costToComplete'])  
    
    labeltype = ["LOW", "MODERATELOW", "MODERATE", "MODERATEHIGH", "HIGH", "HIGHEST", "UNKNOWN"]
    
    for x in labeltype:
        
        one_row.append(data['povertyType'].get(x, 0))
    
    csv_data.append(one_row)

csv_data
# Out:
# [['Daly City', 8266.81, 1, 1, 1, 13, 1, 0, 0],
#  ['Danville', 30718.34, 20, 0, 0, 0, 0, 0, 0],
#  ['Dixon', 1096.23, 0, 1, 1, 0, 0, 0, 0],
#  ['Dublin', 16169.74, 19, 0, 0, 0, 0, 0, 0],
#  ['East Palo Alto', 21437.47, 0, 0, 0, 0, 0, 23, 0],
#  ['El Cerrito', 9935.399999999998, 4, 3, 0, 8, 0, 0, 0],
#  ['Emeryville', 994.62, 0, 0, 0, 1, 0, 0, 0],
#  ['Fairfax', 454.82, 1, 0, 0, 0, 0, 0, 0],
#  ['Fairfield', 27023.86, 0, 16, 0, 2, 0, 15, 0],
#  ['Foster City', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Fremont', 34197.53, 41, 5, 3, 1, 0, 0, 0],
#  ['Gilroy', 9405.53, 0, 3, 8, 2, 1, 0, 0],
#  ['Half Moon Bay', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Hayward', 34049.53, 0, 1, 1, 37, 11, 0, 0],
#  ['Healdsburg', 0, 0, 0, 0, 0, 0, 0, 0],
#  ['Hercules', 16210.6, 0, 6, 0, 0, 0, 0, 3],
#  ['Hillsborough', 0, 0, 0, 0, 0, 0, 0, 0]]

# %%
root_path = os.path.join(os.getcwd())
data_path = os.path.join(root_path)
csvpath = os.path.join(root_path, "donorschoose_api.csv")
with open(csvpath, "a", newline="") as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=",")
    csvwriter.writerows(csv_data)
